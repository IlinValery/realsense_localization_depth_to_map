# %% [markdown]
# Creator: e. tsykunov
#
# 1st edit: a. fedoseev

# %%
import pyrealsense2 as rs
import open3d as o3d
import matplotlib.pyplot as plt
import numpy as np
import cv2
from scipy.spatial.transform import Rotation as R
import copy

# %%
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# # Saving all frames

# %%
# data filenames
d435_filename = 'data/D435.bag'
t265_filename = 'data/T265.bag'

# %% [markdown]
# ### T265

# %%
# Setup:
cfg = rs.config()
cfg.enable_device_from_file(t265_filename)
cfg.enable_stream(rs.stream.pose)
pipe = rs.pipeline()
profile = pipe.start(cfg)

t265_data_list = []
t265_time_list = []
first_timestamp = None
while(True):

    frames = pipe.wait_for_frames()
    pose = frames.get_pose_frame()
    
    if pose:
        if pose.get_timestamp() == first_timestamp:
            print('reached the first frame - reading bag file completed')
            break
        if first_timestamp is None:
            first_timestamp = pose.get_timestamp()
            print('first_timestamp',first_timestamp)
        print('current-first',pose.get_timestamp()-first_timestamp)
        t265_data_list.append(pose.get_pose_data())
        t265_time_list.append(pose.get_timestamp())

pipe.stop()
# Out:
# first_timestamp 1585059273040.0645
# current-first 0.0
# current-first 4.9990234375
# current-first 9.998046875
# current-first 14.9970703125
# current-first 19.9970703125
# current-first 24.99609375
# current-first 29.9951171875
# current-first 34.993896484375
# current-first 39.9931640625
# current-first 44.9931640625
# current-first 49.991943359375
# current-first 54.9912109375
# current-first 59.989990234375
# current-first 64.989013671875
# current-first 69.9892578125
# current-first 74.988037109375
# current-first 79.987060546875
# current-first 84.986083984375
# current-first 89.985107421875
# current-first 94.98388671875
# current-first 99.983154296875
# current-first 104.983154296875
# current-first 109.98193359375
# current-first 114.981201171875
# current-first 119.97998046875
# current-first 124.97998046875
# current-first 129.97900390625
# current-first 134.97802734375
# current-first 139.97705078125
# current-first 144.975830078125
# current-first 149.97509765625
# current-first 154.97509765625
# current-first 159.973876953125
# current-first 164.97314453125
# current-first 169.971923828125
# current-first 174.970947265625
# current-first 179.97021484375
# current-first 184.969970703125
# current-first 189.968994140625
# current-first 194.968017578125
# current-first 199.967041015625
# current-first 204.966064453125
# current-first 209.965087890625
# current-first 214.965087890625
# current-first 219.9638671875
# current-first 224.963134765625
# current-first 229.962158203125
# current-first 234.9609375
# current-first 239.961181640625
# current-first 244.9599609375
# current-first 249.958984375
# current-first 254.958251953125
# current-first 259.95703125
# current-first 264.9560546875
# current-first 269.9560546875
# current-first 274.955078125
# current-first 279.953857421875
# current-first 284.953125
# current-first 289.9521484375
# current-first 294.950927734375
# current-first 299.951171875
# current-first 304.9501953125
# current-first 309.948974609375
# current-first 314.9482421875
# current-first 319.947021484375
# current-first 324.946044921875
# current-first 329.9462890625
# current-first 334.945068359375
# current-first 339.944091796875
# current-first 344.943115234375
# current-first 349.942138671875
# current-first 354.94189453125
# current-first 359.941162109375
# current-first 364.940185546875
# current-first 369.93896484375
# current-first 374.938232421875
# current-first 379.93701171875
# current-first 384.93701171875
# current-first 389.936279296875
# current-first 394.93505859375
# current-first 399.93408203125
# current-first 404.93310546875
# current-first 409.93310546875
# current-first 414.93212890625
# current-first 419.930908203125
# current-first 424.93017578125
# current-first 429.928955078125
# current-first 434.92822265625
# current-first 439.927001953125
# current-first 444.927001953125
# current-first 449.926025390625
# current-first 454.925048828125
# current-first 459.924072265625
# current-first 464.9228515625
# current-first 469.923095703125
# current-first 474.931396484375
# current-first 479.930419921875
# current-first 484.9296875
# current-first 489.928466796875
# current-first 494.928466796875
# current-first 499.927490234375
# current-first 504.926513671875
# current-first 509.925537109375
# current-first 514.924560546875
# current-first 519.923583984375
# current-first 524.92333984375
# current-first 529.922607421875
# current-first 534.921630859375
# current-first 539.92041015625
# current-first 544.919677734375
# current-first 549.91845703125
# current-first 554.91845703125
# current-first 559.917724609375
# current-first 564.91650390625
# current-first 569.91552734375
# current-first 574.91455078125
# current-first 579.91455078125
# current-first 584.91357421875
# current-first 589.91259765625
# current-first 594.91162109375
# current-first 599.910400390625
# current-first 604.90966796875
# current-first 609.90966796875
# current-first 614.908447265625
# current-first 619.90771484375
# current-first 624.906494140625
# current-first 629.906494140625
# current-first 634.90576171875
# current-first 639.904541015625
# current-first 644.903564453125
# current-first 649.902587890625
# current-first 654.901611328125
# current-first 659.900390625
# current-first 664.900390625
# current-first 669.899658203125
# current-first 674.8984375
# current-first 679.897705078125
# current-first 684.896484375
# current-first 689.896484375
# current-first 694.8955078125
# current-first 699.89453125
# current-first 704.8935546875
# current-first 709.892333984375
# current-first 714.8916015625
# current-first 719.8916015625
# current-first 724.890380859375
# current-first 729.8896484375
# current-first 734.888427734375
# current-first 739.887451171875
# current-first 744.8876953125
# current-first 749.886474609375
# current-first 754.885498046875
# current-first 759.884521484375
# current-first 764.883544921875
# current-first 769.88232421875
# current-first 774.882568359375
# current-first 779.881591796875
# current-first 784.88037109375
# current-first 789.879638671875
# current-first 794.87841796875
# current-first 799.87841796875
# current-first 804.877685546875
# current-first 809.87646484375
# current-first 814.87548828125
# current-first 819.87451171875
# current-first 824.87451171875
# current-first 829.87353515625
# current-first 834.87255859375
# current-first 839.87158203125
# current-first 844.870361328125
# current-first 849.86962890625
# current-first 854.86865234375
# current-first 859.868408203125
# current-first 864.86767578125
# current-first 869.866455078125
# current-first 874.865478515625
# current-first 879.86474609375
# current-first 884.864501953125
# current-first 889.863525390625
# current-first 894.862548828125
# current-first 899.861572265625
# current-first 904.860595703125
# current-first 909.8603515625
# current-first 914.859619140625
# current-first 919.8583984375
# current-first 924.857421875
# current-first 929.856689453125
# current-first 934.8564453125
# current-first 939.85546875
# current-first 944.8544921875
# current-first 949.853515625
# current-first 954.852294921875
# current-first 959.8515625
# current-first 964.8515625
# current-first 969.850341796875
# current-first 974.843994140625
# current-first 979.8427734375
# current-first 984.841796875
# current-first 989.842041015625
# current-first 994.8408203125
# current-first 999.83984375
# current-first 1004.8388671875
# current-first 1009.837890625
# current-first 1014.8369140625
# current-first 1019.8369140625
# current-first 1024.8359375
# current-first 1029.834716796875
# current-first 1034.833984375
# current-first 1039.8330078125
# current-first 1044.831787109375
# current-first 1049.83203125
# current-first 1054.830810546875
# current-first 1059.829833984375
# current-first 1064.8291015625
# current-first 1069.827880859375
# current-first 1074.827880859375
# current-first 1079.826904296875
# current-first 1084.825927734375
# current-first 1089.82470703125
# current-first 1094.823974609375
# current-first 1099.823974609375
# current-first 1104.82275390625
# current-first 1109.822021484375
# current-first 1114.821044921875
# current-first 1119.81982421875
# current-first 1124.819091796875
# current-first 1129.81884765625
# current-first 1134.81787109375
# current-first 1139.817138671875
# current-first 1144.81591796875
# current-first 1149.81494140625
# current-first 1154.81396484375
# current-first 1159.81396484375
# current-first 1164.812744140625
# current-first 1169.81201171875
# current-first 1174.81103515625
# current-first 1179.809814453125
# current-first 1184.809814453125
# current-first 1189.808837890625
# current-first 1194.807861328125
# current-first 1199.806884765625
# current-first 1204.805908203125
# current-first 1209.805908203125
# current-first 1214.8046875
# current-first 1219.803955078125
# current-first 1224.802978515625
# current-first 1229.8017578125
# current-first 1234.802001953125
# current-first 1239.80078125
# current-first 1244.7998046875
# current-first 1249.799072265625
# current-first 1254.7978515625
# current-first 1259.796875
# current-first 1264.796875
# current-first 1269.7958984375
# current-first 1274.794921875
# current-first 1279.7939453125
# current-first 1284.7939453125
# current-first 1289.791748046875
# current-first 1294.7919921875
# current-first 1299.791015625
# current-first 1304.789794921875
# current-first 1309.7890625
# current-first 1314.787841796875
# current-first 1319.787841796875
# current-first 1324.787109375
# current-first 1329.785888671875
# current-first 1334.784912109375
# current-first 1339.783935546875
# current-first 1344.783935546875
# current-first 1349.782958984375
# current-first 1354.781982421875
# current-first 1359.781005859375
# current-first 1364.77978515625
# current-first 1369.779052734375
# current-first 1374.779052734375
# current-first 1379.77783203125
# current-first 1384.777099609375
# current-first 1389.77587890625
# current-first 1394.77490234375
# current-first 1399.77392578125
# current-first 1404.77392578125
# current-first 1409.77294921875
# current-first 1414.771728515625
# current-first 1419.77099609375
# current-first 1424.769775390625
# current-first 1429.769775390625
# current-first 1434.76904296875
# current-first 1439.767822265625
# current-first 1444.766845703125
# current-first 1449.765869140625
# current-first 1454.764892578125
# current-first 1459.764892578125
# current-first 1464.763916015625
# current-first 1469.762939453125
# current-first 1474.76171875
# current-first 1479.80078125
# current-first 1484.7998046875
# current-first 1489.798828125
# current-first 1494.7978515625
# current-first 1499.796875
# current-first 1504.795654296875
# current-first 1509.794921875
# current-first 1514.794921875
# current-first 1519.793701171875
# current-first 1524.79296875
# current-first 1529.791748046875
# current-first 1534.790771484375
# current-first 1539.791015625
# current-first 1544.789794921875
# current-first 1549.788818359375
# current-first 1554.787841796875
# current-first 1559.786865234375
# current-first 1564.786865234375
# current-first 1569.785888671875
# current-first 1574.784912109375
# current-first 1579.78369140625
# current-first 1584.782958984375
# current-first 1589.782958984375
# current-first 1594.78173828125
# current-first 1599.781005859375
# current-first 1604.77978515625
# current-first 1609.77880859375
# current-first 1614.77783203125
# current-first 1619.77783203125
# current-first 1624.77685546875
# current-first 1629.77587890625
# current-first 1634.77490234375
# current-first 1639.773681640625
# current-first 1644.773681640625
# current-first 1649.77294921875
# current-first 1654.771728515625
# current-first 1659.77099609375
# current-first 1664.769775390625
# current-first 1669.769775390625
# current-first 1674.768798828125
# current-first 1679.767822265625
# current-first 1684.766845703125
# current-first 1689.765625
# current-first 1694.764892578125
# current-first 1699.764892578125
# current-first 1704.763671875
# current-first 1709.762939453125
# current-first 1714.76171875
# current-first 1719.7607421875
# current-first 1724.760986328125
# current-first 1729.759765625
# current-first 1734.7587890625
# current-first 1739.7578125
# current-first 1744.7568359375
# current-first 1749.7568359375
# current-first 1754.755859375
# current-first 1759.7548828125
# current-first 1764.753662109375
# current-first 1769.7529296875
# current-first 1774.751708984375
# current-first 1779.751708984375
# current-first 1784.7509765625
# current-first 1789.749755859375
# current-first 1794.748779296875
# current-first 1799.747802734375
# current-first 1804.747802734375
# current-first 1809.746826171875
# current-first 1814.745849609375
# current-first 1819.744873046875
# current-first 1824.74365234375
# current-first 1829.743896484375
# current-first 1834.742919921875
# current-first 1839.74169921875
# current-first 1844.740966796875
# current-first 1849.73974609375
# current-first 1854.73876953125
# current-first 1859.73876953125
# current-first 1864.73779296875
# current-first 1869.73681640625
# current-first 1874.73583984375
# current-first 1879.73486328125
# current-first 1884.73486328125
# current-first 1889.733642578125
# current-first 1894.73291015625
# current-first 1899.731689453125
# current-first 1904.730712890625
# current-first 1909.729736328125
# current-first 1914.729736328125
# current-first 1919.728759765625
# current-first 1924.727783203125
# current-first 1929.726806640625
# current-first 1934.7255859375
# current-first 1939.725830078125
# current-first 1944.724853515625
# current-first 1949.7236328125
# current-first 1954.722900390625
# current-first 1959.7216796875
# current-first 1964.7216796875
# current-first 1969.720947265625
# current-first 1974.7197265625
# current-first 1979.85986328125
# current-first 1984.85888671875
# current-first 1989.85888671875
# current-first 1994.857666015625
# current-first 1999.85693359375
# current-first 2004.85595703125
# current-first 2009.854736328125
# current-first 2014.85498046875
# current-first 2019.85400390625
# current-first 2024.852783203125
# current-first 2029.85205078125
# current-first 2034.850830078125
# current-first 2039.849853515625
# current-first 2044.85009765625
# current-first 2049.848876953125
# current-first 2054.847900390625
# current-first 2059.846923828125
# current-first 2064.845947265625
# current-first 2069.845703125
# current-first 2074.844970703125
# current-first 2079.843994140625
# current-first 2084.8427734375
# current-first 2089.842041015625
# current-first 2094.8408203125
# current-first 2099.8408203125
# current-first 2104.83984375
# current-first 2109.8388671875
# current-first 2114.837890625
# current-first 2119.8369140625
# current-first 2124.8369140625
# current-first 2129.8359375
# current-first 2134.834716796875
# current-first 2139.833984375
# current-first 2144.832763671875
# current-first 2149.831787109375
# current-first 2154.83203125
# current-first 2159.830810546875
# current-first 2164.829833984375
# current-first 2169.828857421875
# current-first 2174.827880859375
# current-first 2179.827880859375
# current-first 2184.826904296875
# current-first 2189.825927734375
# current-first 2194.82470703125
# current-first 2199.823974609375
# current-first 2204.82275390625
# current-first 2209.82275390625
# current-first 2214.822021484375
# current-first 2219.82080078125
# current-first 2224.81982421875
# current-first 2229.81884765625
# current-first 2234.81884765625
# current-first 2239.81787109375
# current-first 2244.81689453125
# current-first 2249.81591796875
# current-first 2254.814697265625
# current-first 2259.81396484375
# current-first 2264.81396484375
# current-first 2269.812744140625
# current-first 2274.81201171875
# current-first 2279.810791015625
# current-first 2284.810791015625
# current-first 2289.81005859375
# current-first 2294.808837890625
# current-first 2299.807861328125
# current-first 2304.806884765625
# current-first 2309.805908203125
# current-first 2314.805908203125
# current-first 2319.804931640625
# current-first 2324.803955078125
# current-first 2329.802734375
# current-first 2334.802001953125
# current-first 2339.802001953125
# current-first 2344.80078125
# current-first 2349.800048828125
# current-first 2354.798828125
# current-first 2359.7978515625
# current-first 2364.796875
# current-first 2369.7958984375
# current-first 2374.7958984375
# current-first 2379.794677734375
# current-first 2384.7939453125
# current-first 2389.792724609375
# current-first 2394.792724609375
# current-first 2399.7919921875
# current-first 2404.790771484375
# current-first 2409.789794921875
# current-first 2414.7900390625
# current-first 2419.788818359375
# current-first 2424.787841796875
# current-first 2429.786865234375
# current-first 2434.785888671875
# current-first 2439.785888671875
# current-first 2444.784912109375
# current-first 2449.783935546875
# current-first 2454.78271484375
# current-first 2459.781982421875
# current-first 2464.78076171875
# current-first 2469.78076171875
# current-first 2474.780029296875
# current-first 2479.65869140625
# current-first 2484.65771484375
# current-first 2489.656982421875
# current-first 2494.65576171875
# current-first 2499.65576171875
# current-first 2504.65478515625
# current-first 2509.65380859375
# current-first 2514.65283203125
# current-first 2519.65283203125
# current-first 2524.65185546875
# current-first 2529.650634765625
# current-first 2534.64990234375
# current-first 2539.64892578125
# current-first 2544.648681640625
# current-first 2549.64794921875
# current-first 2554.646728515625
# current-first 2559.645751953125
# current-first 2564.64501953125
# current-first 2569.643798828125
# current-first 2574.643798828125
# current-first 2579.642578125
# current-first 2584.641845703125
# current-first 2589.640869140625
# current-first 2594.639892578125
# current-first 2599.638916015625
# current-first 2604.638671875
# current-first 2609.6376953125
# current-first 2614.636962890625
# current-first 2619.6357421875
# current-first 2624.634765625
# current-first 2629.634765625
# current-first 2634.6337890625
# current-first 2639.6328125
# current-first 2644.6318359375
# current-first 2649.6318359375
# current-first 2654.630615234375
# current-first 2659.6298828125
# current-first 2664.62890625
# current-first 2669.627685546875
# current-first 2674.626953125
# current-first 2679.626708984375
# current-first 2684.625732421875
# current-first 2689.625
# current-first 2694.623779296875
# current-first 2699.622802734375
# current-first 2704.621826171875
# current-first 2709.621826171875
# current-first 2714.620849609375
# current-first 2719.619873046875
# current-first 2724.618896484375
# current-first 2729.61767578125
# current-first 2734.616943359375
# current-first 2739.616943359375
# current-first 2744.61572265625
# current-first 2749.614990234375
# current-first 2754.61376953125
# current-first 2759.61376953125
# current-first 2764.613037109375
# current-first 2769.61181640625
# current-first 2774.61083984375
# current-first 2779.60986328125
# current-first 2784.60986328125
# current-first 2789.608642578125
# current-first 2794.607666015625
# current-first 2799.60693359375
# current-first 2804.605712890625
# current-first 2809.60498046875
# current-first 2814.60498046875
# current-first 2819.603759765625
# current-first 2824.602783203125
# current-first 2829.601806640625
# current-first 2834.600830078125
# current-first 2839.6005859375
# current-first 2844.599853515625
# current-first 2849.598876953125
# current-first 2854.59765625
# current-first 2859.596923828125
# current-first 2864.595703125
# current-first 2869.595703125
# current-first 2874.594970703125
# current-first 2879.59375
# current-first 2884.5927734375
# current-first 2889.591796875
# current-first 2894.591796875
# current-first 2899.5908203125
# current-first 2904.58984375
# current-first 2909.5888671875
# current-first 2914.587646484375
# current-first 2919.587890625
# current-first 2924.5869140625
# current-first 2929.585693359375
# current-first 2934.5849609375
# current-first 2939.583740234375
# current-first 2944.583740234375
# current-first 2949.5830078125
# current-first 2954.581787109375
# current-first 2959.580810546875
# current-first 2964.579833984375
# current-first 2969.579833984375
# current-first 2974.578857421875
# current-first 2979.549072265625
# current-first 2984.5478515625
# current-first 2989.546875
# current-first 2994.5458984375
# current-first 2999.5458984375
# current-first 3004.544921875
# current-first 3009.5439453125
# current-first 3014.54296875
# current-first 3019.541748046875
# current-first 3024.541015625
# current-first 3029.541015625
# current-first 3034.539794921875
# current-first 3039.538818359375
# current-first 3044.537841796875
# current-first 3049.537841796875
# current-first 3054.536865234375
# current-first 3059.535888671875
# current-first 3064.534912109375
# current-first 3069.53369140625
# current-first 3074.532958984375
# current-first 3079.532958984375
# current-first 3084.53173828125
# current-first 3089.531005859375
# current-first 3094.52978515625
# current-first 3099.52880859375
# current-first 3104.529052734375
# current-first 3109.52783203125
# current-first 3114.52685546875
# current-first 3119.52587890625
# current-first 3124.52490234375
# current-first 3129.52490234375
# current-first 3134.52392578125
# current-first 3139.52294921875
# current-first 3144.521728515625
# current-first 3149.52099609375
# current-first 3154.52099609375
# current-first 3159.519775390625
# current-first 3164.51904296875
# current-first 3169.517822265625
# current-first 3174.516845703125
# current-first 3179.515869140625
# current-first 3184.515869140625
# current-first 3189.514892578125
# current-first 3194.513916015625
# current-first 3199.512939453125
# current-first 3204.51171875
# current-first 3209.511962890625
# current-first 3214.510986328125
# current-first 3219.509765625
# current-first 3224.509033203125
# current-first 3229.5078125
# current-first 3234.5078125
# current-first 3239.507080078125
# current-first 3244.505859375
# current-first 3249.5048828125
# current-first 3254.50390625
# current-first 3259.50390625
# current-first 3264.5029296875
# current-first 3269.501708984375
# current-first 3274.5009765625
# current-first 3279.499755859375
# current-first 3284.499755859375
# current-first 3289.4990234375
# current-first 3294.497802734375
# current-first 3299.496826171875
# current-first 3304.495849609375
# current-first 3309.494873046875
# current-first 3314.494873046875
# current-first 3319.493896484375
# current-first 3324.492919921875
# current-first 3329.49169921875
# current-first 3334.490966796875
# current-first 3339.490966796875
# current-first 3344.48974609375
# current-first 3349.489013671875
# current-first 3354.48779296875
# current-first 3359.48681640625
# current-first 3364.487060546875
# current-first 3369.48583984375
# current-first 3374.48486328125
# current-first 3379.48388671875
# current-first 3384.48291015625
# current-first 3389.481689453125
# current-first 3394.48193359375
# current-first 3399.48095703125
# current-first 3404.479736328125
# current-first 3409.47900390625
# current-first 3414.477783203125
# current-first 3419.477783203125
# current-first 3424.47705078125
# current-first 3429.475830078125
# current-first 3434.474853515625
# current-first 3439.473876953125
# current-first 3444.473876953125
# current-first 3449.472900390625
# current-first 3454.471923828125
# current-first 3459.470947265625
# current-first 3464.470947265625
# current-first 3469.4697265625
# current-first 3474.468994140625
# current-first 3479.4677734375
# current-first 3484.609130859375
# current-first 3489.608154296875
# current-first 3494.607177734375
# current-first 3499.607177734375
# current-first 3504.606201171875
# current-first 3509.605224609375
# current-first 3514.60400390625
# current-first 3519.603271484375
# current-first 3524.603271484375
# current-first 3529.60205078125
# current-first 3534.601318359375
# current-first 3539.60009765625
# current-first 3544.59912109375
# current-first 3549.599365234375
# current-first 3554.59814453125
# current-first 3559.59716796875
# current-first 3564.59619140625
# current-first 3569.59521484375
# current-first 3574.59521484375
# current-first 3579.59423828125
# current-first 3584.59326171875
# current-first 3589.592041015625
# current-first 3594.59130859375
# current-first 3599.590087890625
# current-first 3604.590087890625
# current-first 3609.58935546875
# current-first 3614.588134765625
# current-first 3619.587158203125
# current-first 3624.586181640625
# current-first 3629.586181640625
# current-first 3634.585205078125
# current-first 3639.584228515625
# current-first 3644.583251953125
# current-first 3649.58203125
# current-first 3654.582275390625
# current-first 3659.581298828125
# current-first 3664.580078125
# current-first 3669.579345703125
# current-first 3674.579345703125
# current-first 3679.578125
# current-first 3684.577392578125
# current-first 3689.576171875
# current-first 3694.5751953125
# current-first 3699.57421875
# current-first 3704.5732421875
# current-first 3709.5732421875
# current-first 3714.572021484375
# current-first 3719.5712890625
# current-first 3724.570068359375
# current-first 3729.5693359375
# current-first 3734.5693359375
# current-first 3739.568115234375
# current-first 3744.567138671875
# current-first 3749.566162109375
# current-first 3754.566162109375
# current-first 3759.565185546875
# current-first 3764.564208984375
# current-first 3769.563232421875
# current-first 3774.56201171875
# current-first 3779.562255859375
# current-first 3784.561279296875
# current-first 3789.56005859375
# current-first 3794.559326171875
# current-first 3799.55810546875
# current-first 3804.55712890625
# current-first 3809.557373046875
# current-first 3814.55615234375
# current-first 3819.55517578125
# current-first 3824.55419921875
# current-first 3829.55322265625
# current-first 3834.55322265625
# current-first 3839.55224609375
# current-first 3844.55126953125
# current-first 3849.550048828125
# current-first 3854.54931640625
# current-first 3859.54931640625
# current-first 3864.548095703125
# current-first 3869.54736328125
# current-first 3874.546142578125
# current-first 3879.546142578125
# current-first 3884.545166015625
# current-first 3889.544189453125
# current-first 3894.543212890625
# current-first 3899.542236328125
# current-first 3904.541259765625
# current-first 3909.541259765625
# current-first 3914.5400390625
# current-first 3919.539306640625
# current-first 3924.5380859375
# current-first 3929.537109375
# current-first 3934.5361328125
# current-first 3939.5361328125
# current-first 3944.53515625
# current-first 3949.5341796875
# current-first 3954.533203125
# current-first 3959.533203125
# current-first 3964.5322265625
# current-first 3969.53125
# current-first 3974.530029296875
# current-first 3979.529296875
# current-first 3984.3388671875
# current-first 3989.338623046875
# current-first 3994.337890625
# current-first 3999.336669921875
# current-first 4004.335693359375
# current-first 4009.3349609375
# current-first 4014.334716796875
# current-first 4019.333740234375
# current-first 4024.332763671875
# current-first 4029.331787109375
# current-first 4034.331787109375
# current-first 4039.330810546875
# current-first 4044.329833984375
# current-first 4049.32861328125
# current-first 4054.327880859375
# current-first 4059.32666015625
# current-first 4064.32568359375
# current-first 4069.325927734375
# current-first 4074.32470703125
# current-first 4079.32373046875
# current-first 4084.32275390625
# current-first 4089.32275390625
# current-first 4094.32177734375
# current-first 4099.32080078125
# current-first 4104.31982421875
# current-first 4109.318603515625
# current-first 4114.31787109375
# current-first 4119.31787109375
# current-first 4124.316650390625
# current-first 4129.31591796875
# current-first 4134.314697265625
# current-first 4139.314697265625
# current-first 4144.313720703125
# current-first 4149.312744140625
# current-first 4154.311767578125
# current-first 4159.310546875
# current-first 4164.309814453125
# current-first 4169.309814453125
# current-first 4174.30859375
# current-first 4179.307861328125
# current-first 4184.306640625
# current-first 4189.3056640625
# current-first 4194.305908203125
# current-first 4199.3046875
# current-first 4204.3037109375
# current-first 4209.302734375
# current-first 4214.3017578125
# current-first 4219.3017578125
# current-first 4224.30078125
# current-first 4229.2998046875
# current-first 4234.298583984375
# current-first 4239.2978515625
# current-first 4244.2978515625
# current-first 4249.296630859375
# current-first 4254.2958984375
# current-first 4259.294677734375
# current-first 4264.293701171875
# current-first 4269.2939453125
# current-first 4274.292724609375
# current-first 4279.291748046875
# current-first 4284.290771484375
# current-first 4289.289794921875
# current-first 4294.289794921875
# current-first 4299.288818359375
# current-first 4304.287841796875
# current-first 4309.28662109375
# current-first 4314.285888671875
# current-first 4319.284912109375
# current-first 4324.28466796875
# current-first 4329.28369140625
# current-first 4334.28271484375
# current-first 4339.28173828125
# current-first 4344.281005859375
# current-first 4349.28076171875
# current-first 4354.27978515625
# current-first 4359.278564453125
# current-first 4364.27783203125
# current-first 4369.276611328125
# current-first 4374.276611328125
# current-first 4379.27587890625
# current-first 4384.274658203125
# current-first 4389.273681640625
# current-first 4394.272705078125
# current-first 4399.272705078125
# current-first 4404.271728515625
# current-first 4409.270751953125
# current-first 4414.269775390625
# current-first 4419.2685546875
# current-first 4424.268798828125
# current-first 4429.267822265625
# current-first 4434.2666015625
# current-first 4439.265869140625
# current-first 4444.2646484375
# current-first 4449.2646484375
# current-first 4454.263916015625
# current-first 4459.2626953125
# current-first 4464.26171875
# current-first 4469.2607421875
# current-first 4474.2607421875
# current-first 4479.259765625
# current-first 4484.470703125
# current-first 4489.469482421875
# current-first 4494.468505859375
# current-first 4499.467529296875
# current-first 4504.467529296875
# current-first 4509.46630859375
# current-first 4514.465576171875
# current-first 4519.464599609375
# current-first 4524.46337890625
# current-first 4529.46337890625
# current-first 4534.46240234375
# current-first 4539.46142578125
# current-first 4544.460693359375
# current-first 4549.45947265625
# current-first 4554.45947265625
# current-first 4559.458251953125
# current-first 4564.45751953125
# current-first 4569.45654296875
# current-first 4574.455322265625
# current-first 4579.45556640625
# current-first 4584.454345703125
# current-first 4589.453369140625
# current-first 4594.45263671875
# current-first 4599.451416015625
# current-first 4604.451416015625
# current-first 4609.450439453125
# current-first 4614.449462890625
# current-first 4619.448486328125
# current-first 4624.447509765625
# current-first 4629.447509765625
# current-first 4634.4462890625
# current-first 4639.445556640625
# current-first 4644.444580078125
# current-first 4649.443359375
# current-first 4654.443603515625
# current-first 4659.4423828125
# current-first 4664.44140625
# current-first 4669.440673828125
# current-first 4674.439453125
# current-first 4679.4384765625
# current-first 4684.4384765625
# current-first 4689.4375
# current-first 4694.4365234375
# current-first 4699.435546875
# current-first 4704.435546875
# current-first 4709.434326171875
# current-first 4714.43359375
# current-first 4719.4326171875
# current-first 4724.431396484375
# current-first 4729.4306640625
# current-first 4734.430419921875
# current-first 4739.429443359375
# current-first 4744.4287109375
# current-first 4749.427490234375
# current-first 4754.426513671875
# current-first 4759.42626953125
# current-first 4764.425537109375
# current-first 4769.424560546875
# current-first 4774.423583984375
# current-first 4779.422607421875
# current-first 4784.42236328125
# current-first 4789.42138671875
# current-first 4794.420654296875
# current-first 4799.41943359375
# current-first 4804.41845703125
# current-first 4809.41845703125
# current-first 4814.41748046875
# current-first 4819.416259765625
# current-first 4824.41552734375
# current-first 4829.41455078125
# current-first 4834.414306640625
# current-first 4839.41357421875
# current-first 4844.412353515625
# current-first 4849.411376953125
# current-first 4854.41064453125
# current-first 4859.409423828125
# current-first 4864.409423828125
# current-first 4869.40869140625
# current-first 4874.407470703125
# current-first 4879.406494140625
# current-first 4884.406494140625
# current-first 4889.405517578125
# current-first 4894.404296875
# current-first 4899.403564453125
# current-first 4904.402587890625
# current-first 4909.40234375
# current-first 4914.401611328125
# current-first 4919.400390625
# current-first 4924.3994140625
# current-first 4929.398681640625
# current-first 4934.3984375
# current-first 4939.3974609375
# current-first 4944.396484375
# current-first 4949.3955078125
# current-first 4954.39453125
# current-first 4959.3935546875
# current-first 4964.3935546875
# current-first 4969.392333984375
# current-first 4974.391357421875
# current-first 4979.390625
# current-first 4984.389404296875
# current-first 4989.260498046875
# current-first 4994.259765625
# current-first 4999.2587890625
# current-first 5004.257568359375
# current-first 5009.2568359375
# current-first 5014.256591796875
# current-first 5019.255615234375
# current-first 5024.2548828125
# current-first 5029.253662109375
# current-first 5034.252685546875
# current-first 5039.252685546875
# current-first 5044.251708984375
# current-first 5049.250732421875
# current-first 5054.249755859375
# current-first 5059.248779296875
# current-first 5064.24853515625
# current-first 5069.247802734375
# current-first 5074.246826171875
# current-first 5079.24560546875
# current-first 5084.244873046875
# current-first 5089.24365234375
# current-first 5094.24365234375
# current-first 5099.242919921875
# current-first 5104.24169921875
# current-first 5109.24072265625
# current-first 5114.24072265625
# current-first 5119.23974609375
# current-first 5124.23876953125
# current-first 5129.23779296875
# current-first 5134.23681640625
# current-first 5139.236572265625
# current-first 5144.23583984375
# current-first 5149.23486328125
# current-first 5154.233642578125
# current-first 5159.23291015625
# current-first 5164.231689453125
# current-first 5169.231689453125
# current-first 5174.23046875
# current-first 5179.229736328125
# current-first 5184.228759765625
# current-first 5189.228515625
# current-first 5194.227783203125
# current-first 5199.2265625
# current-first 5204.2255859375
# current-first 5209.224853515625
# current-first 5214.224609375
# current-first 5219.2236328125
# current-first 5224.222900390625
# current-first 5229.2216796875
# current-first 5234.220703125
# current-first 5239.220703125
# current-first 5244.2197265625
# current-first 5249.218505859375
# current-first 5254.2177734375
# current-first 5259.216796875
# current-first 5264.216552734375
# current-first 5269.2158203125
# current-first 5274.214599609375
# current-first 5279.213623046875
# current-first 5284.212890625
# current-first 5289.211669921875
# current-first 5294.211669921875
# current-first 5299.210693359375
# current-first 5304.209716796875
# current-first 5309.208740234375
# current-first 5314.208740234375
# current-first 5319.207763671875
# current-first 5324.20654296875
# current-first 5329.205810546875
# current-first 5334.204833984375
# current-first 5339.20458984375
# current-first 5344.203857421875
# current-first 5349.20263671875
# current-first 5354.20166015625
# current-first 5359.200927734375
# current-first 5364.20068359375
# current-first 5369.19970703125
# current-first 5374.19873046875
# current-first 5379.19775390625
# current-first 5384.19677734375
# current-first 5389.19580078125
# current-first 5394.19580078125
# current-first 5399.194580078125
# current-first 5404.193603515625
# current-first 5409.19287109375
# current-first 5414.191650390625
# current-first 5419.191650390625
# current-first 5424.190673828125
# current-first 5429.189697265625
# current-first 5434.188720703125
# current-first 5439.187744140625
# current-first 5444.187744140625
# current-first 5449.1865234375
# current-first 5454.185791015625
# current-first 5459.184814453125
# current-first 5464.18359375
# current-first 5469.183837890625
# current-first 5474.1826171875
# current-first 5479.181640625
# current-first 5484.180908203125
# current-first 5489.173583984375
# current-first 5494.173583984375
# current-first 5499.172607421875
# current-first 5504.171630859375
# current-first 5509.17041015625
# current-first 5514.169677734375
# current-first 5519.169677734375
# current-first 5524.16845703125
# current-first 5529.167724609375
# current-first 5534.16650390625
# current-first 5539.16552734375
# current-first 5544.165771484375
# current-first 5549.16455078125
# current-first 5554.16357421875
# current-first 5559.16259765625
# current-first 5564.16162109375
# current-first 5569.16162109375
# current-first 5574.160400390625
# current-first 5579.15966796875
# current-first 5584.158447265625
# current-first 5589.15771484375
# current-first 5594.15771484375
# current-first 5599.156494140625
# current-first 5604.155517578125
# current-first 5609.154541015625
# current-first 5614.153564453125
# current-first 5619.153564453125
# current-first 5624.152587890625
# current-first 5629.151611328125
# current-first 5634.150390625
# current-first 5639.149658203125
# current-first 5644.149658203125
# current-first 5649.1484375
# current-first 5654.147705078125
# current-first 5659.146484375
# current-first 5664.1455078125
# current-first 5669.145751953125
# current-first 5674.14453125
# current-first 5679.1435546875
# current-first 5684.142578125
# current-first 5689.1416015625
# current-first 5694.1416015625
# current-first 5699.140625
# current-first 5704.1396484375
# current-first 5709.138427734375
# current-first 5714.1376953125
# current-first 5719.1376953125
# current-first 5724.136474609375
# current-first 5729.1357421875
# current-first 5734.134521484375
# current-first 5739.133544921875
# current-first 5744.132568359375
# current-first 5749.132568359375
# current-first 5754.131591796875
# current-first 5759.130615234375
# current-first 5764.129638671875
# current-first 5769.12841796875
# current-first 5774.128662109375
# current-first 5779.127685546875
# current-first 5784.12646484375
# current-first 5789.125732421875
# current-first 5794.125732421875
# current-first 5799.12451171875
# current-first 5804.12353515625
# current-first 5809.12255859375
# current-first 5814.12158203125
# current-first 5819.12060546875
# current-first 5824.12060546875
# current-first 5829.11962890625
# current-first 5834.118408203125
# current-first 5839.11767578125
# current-first 5844.11767578125
# current-first 5849.116455078125
# current-first 5854.11572265625
# current-first 5859.114501953125
# current-first 5864.113525390625
# current-first 5869.11376953125
# current-first 5874.112548828125
# current-first 5879.111572265625
# current-first 5884.110595703125
# current-first 5889.109619140625
# current-first 5894.109619140625
# current-first 5899.108642578125
# current-first 5904.107666015625
# current-first 5909.1064453125
# current-first 5914.105712890625
# current-first 5919.105712890625
# current-first 5924.1044921875
# current-first 5929.103759765625
# current-first 5934.1025390625
# current-first 5939.1015625
# current-first 5944.101806640625
# current-first 5949.1005859375
# current-first 5954.099609375
# current-first 5959.0986328125
# current-first 5964.09765625
# current-first 5969.096435546875
# current-first 5974.096435546875
# current-first 5979.095703125
# current-first 5984.094482421875
# current-first 5989.0654296875
# current-first 5994.064453125
# current-first 5999.064453125
# current-first 6004.063232421875
# current-first 6009.0625
# current-first 6014.061279296875
# current-first 6019.061279296875
# current-first 6024.060546875
# current-first 6029.059326171875
# current-first 6034.058349609375
# current-first 6039.057373046875
# current-first 6044.057373046875
# current-first 6049.056396484375
# current-first 6054.055419921875
# current-first 6059.054443359375
# current-first 6064.05322265625
# current-first 6069.052490234375
# current-first 6074.052490234375
# current-first 6079.05126953125
# current-first 6084.050537109375
# current-first 6089.04931640625
# current-first 6094.04833984375
# current-first 6099.048583984375
# current-first 6104.04736328125
# current-first 6109.04638671875
# current-first 6114.04541015625
# current-first 6119.04541015625
# current-first 6124.04443359375
# current-first 6129.04345703125
# current-first 6134.04248046875
# current-first 6139.041259765625
# current-first 6144.04150390625
# current-first 6149.04052734375
# current-first 6154.039306640625
# current-first 6159.03857421875
# current-first 6164.037353515625
# current-first 6169.037353515625
# current-first 6174.03662109375
# current-first 6179.035400390625
# current-first 6184.034423828125
# current-first 6189.033447265625
# current-first 6194.033447265625
# current-first 6199.032470703125
# current-first 6204.03125
# current-first 6209.030517578125
# current-first 6214.029296875
# current-first 6219.028564453125
# current-first 6224.028564453125
# current-first 6229.02734375
# current-first 6234.0263671875
# current-first 6239.025390625
# current-first 6244.025390625
# current-first 6249.0244140625
# current-first 6254.0234375
# current-first 6259.0224609375
# current-first 6264.021240234375
# current-first 6269.021484375
# current-first 6274.0205078125
# current-first 6279.019287109375
# current-first 6284.0185546875
# current-first 6289.017333984375
# current-first 6294.017333984375
# current-first 6299.0166015625
# current-first 6304.015380859375
# current-first 6309.014404296875
# current-first 6314.013427734375
# current-first 6319.013427734375
# current-first 6324.012451171875
# current-first 6329.011474609375
# current-first 6334.010498046875
# current-first 6339.00927734375
# current-first 6344.009521484375
# current-first 6349.008544921875
# current-first 6354.00732421875
# current-first 6359.006591796875
# current-first 6364.00537109375
# current-first 6369.00537109375
# current-first 6374.00439453125
# current-first 6379.00341796875
# current-first 6384.00244140625
# current-first 6389.00146484375
# current-first 6394.00146484375
# current-first 6399.00048828125
# current-first 6403.999267578125
# current-first 6408.99853515625
# current-first 6413.997314453125
# current-first 6418.997314453125
# current-first 6423.99658203125
# current-first 6428.995361328125
# current-first 6433.994384765625
# current-first 6438.993408203125
# current-first 6443.993408203125
# current-first 6448.992431640625
# current-first 6453.991455078125
# current-first 6458.990478515625
# current-first 6463.9892578125
# current-first 6468.989501953125
# current-first 6473.988525390625
# current-first 6478.9873046875
# current-first 6483.986572265625
# current-first 6488.9853515625
# current-first 6494.02099609375
# current-first 6499.02001953125
# current-first 6504.01904296875
# current-first 6509.017822265625
# current-first 6514.01708984375
# current-first 6519.01708984375
# current-first 6524.015869140625
# current-first 6529.01513671875
# current-first 6534.013916015625
# current-first 6539.012939453125
# current-first 6544.01318359375
# current-first 6549.011962890625
# current-first 6554.010986328125
# current-first 6559.010009765625
# current-first 6564.009033203125
# current-first 6569.009033203125
# current-first 6574.0078125
# current-first 6579.007080078125
# current-first 6584.005859375
# current-first 6589.005126953125
# current-first 6594.005126953125
# current-first 6599.00390625
# current-first 6604.0029296875
# current-first 6609.001953125
# current-first 6614.0009765625
# current-first 6619.0009765625
# current-first 6624.0
# current-first 6628.9990234375
# current-first 6633.997802734375
# current-first 6638.9970703125
# current-first 6643.9970703125
# current-first 6648.995849609375
# current-first 6653.9951171875
# current-first 6658.993896484375
# current-first 6663.992919921875
# current-first 6668.9931640625
# current-first 6673.991943359375
# current-first 6678.990966796875
# current-first 6683.989990234375
# current-first 6688.989013671875
# current-first 6693.989013671875
# current-first 6698.988037109375
# current-first 6703.987060546875
# current-first 6708.98583984375
# current-first 6713.985107421875
# current-first 6718.985107421875
# current-first 6723.98388671875
# current-first 6728.983154296875
# current-first 6733.98193359375
# current-first 6738.98095703125
# current-first 6743.981201171875
# current-first 6748.97998046875
# current-first 6753.97900390625
# current-first 6758.97802734375
# current-first 6763.97705078125
# current-first 6768.97705078125
# current-first 6773.97607421875
# current-first 6778.97509765625
# current-first 6783.973876953125
# current-first 6788.97314453125
# current-first 6793.97314453125
# current-first 6798.971923828125
# current-first 6803.970947265625
# current-first 6808.969970703125
# current-first 6813.969970703125
# current-first 6818.968994140625
# current-first 6823.968017578125
# current-first 6828.967041015625
# current-first 6833.9658203125
# current-first 6838.966064453125
# current-first 6843.965087890625
# current-first 6848.9638671875
# current-first 6853.963134765625
# current-first 6858.9619140625
# current-first 6863.9609375
# current-first 6868.961181640625
# current-first 6873.9599609375
# current-first 6878.958984375
# current-first 6883.9580078125
# current-first 6888.95703125
# current-first 6893.95703125
# current-first 6898.9560546875
# current-first 6903.955078125
# current-first 6908.953857421875
# current-first 6913.9541015625
# current-first 6918.953125
# current-first 6923.951904296875
# current-first 6928.951171875
# current-first 6933.949951171875
# current-first 6938.949951171875
# current-first 6943.94921875
# current-first 6948.947998046875
# current-first 6953.947021484375
# current-first 6958.946044921875
# current-first 6963.946044921875
# current-first 6968.945068359375
# current-first 6973.94384765625
# current-first 6978.943115234375
# current-first 6983.94287109375
# current-first 6988.94189453125
# current-first 6993.95458984375
# current-first 6998.95361328125
# current-first 7003.952392578125
# current-first 7008.95263671875
# current-first 7013.95166015625
# current-first 7018.950439453125
# current-first 7023.94970703125
# current-first 7028.948486328125
# current-first 7033.947509765625
# current-first 7038.94775390625
# current-first 7043.946533203125
# current-first 7048.945556640625
# current-first 7053.944580078125
# current-first 7058.943603515625
# current-first 7063.943603515625
# current-first 7068.942626953125
# current-first 7073.941650390625
# current-first 7078.9404296875
# current-first 7083.939697265625
# current-first 7088.939697265625
# current-first 7093.9384765625
# current-first 7098.937744140625
# current-first 7103.9365234375
# current-first 7108.9365234375
# current-first 7113.935791015625
# current-first 7118.9345703125
# current-first 7123.93359375
# current-first 7128.9326171875
# current-first 7133.9326171875
# current-first 7138.931396484375
# current-first 7143.9306640625
# current-first 7148.9296875
# current-first 7153.928466796875
# current-first 7158.928466796875
# current-first 7163.927490234375
# current-first 7168.926513671875
# current-first 7173.925537109375
# current-first 7178.924560546875
# current-first 7183.923583984375
# current-first 7188.92333984375
# current-first 7193.922607421875
# current-first 7198.921630859375
# current-first 7203.92041015625
# current-first 7208.919677734375
# current-first 7213.91943359375
# current-first 7218.91845703125
# current-first 7223.917724609375
# current-first 7228.91650390625
# current-first 7233.91552734375
# current-first 7238.91552734375
# current-first 7243.91455078125
# current-first 7248.91357421875
# current-first 7253.91259765625
# current-first 7258.91259765625
# current-first 7263.911376953125
# current-first 7268.91064453125
# current-first 7273.90966796875
# current-first 7278.908447265625
# current-first 7283.90869140625
# current-first 7288.907470703125
# current-first 7293.906494140625
# current-first 7298.90576171875
# current-first 7303.904541015625
# current-first 7308.904541015625
# current-first 7313.903564453125
# current-first 7318.902587890625
# current-first 7323.901611328125
# current-first 7328.900634765625
# current-first 7333.900634765625
# current-first 7338.8994140625
# current-first 7343.898681640625
# current-first 7348.897705078125
# current-first 7353.896484375
# current-first 7358.896484375
# current-first 7363.8955078125
# current-first 7368.89453125
# current-first 7373.893798828125
# current-first 7378.892578125
# current-first 7383.892578125
# current-first 7388.891357421875
# current-first 7393.890625
# current-first 7398.8896484375
# current-first 7403.888427734375
# current-first 7408.888671875
# current-first 7413.887451171875
# current-first 7418.886474609375
# current-first 7423.8857421875
# current-first 7428.884521484375
# current-first 7433.884521484375
# current-first 7438.883544921875
# current-first 7443.882568359375
# current-first 7448.88134765625
# current-first 7453.881591796875
# current-first 7458.880615234375
# current-first 7463.87939453125
# current-first 7468.878662109375
# current-first 7473.87744140625
# current-first 7478.87646484375
# current-first 7483.876708984375
# current-first 7488.87548828125
# current-first 7493.873291015625
# current-first 7498.872314453125
# current-first 7503.872314453125
# current-first 7508.871337890625
# current-first 7513.870361328125
# current-first 7518.869384765625
# current-first 7523.8681640625
# current-first 7528.868408203125
# current-first 7533.867431640625
# current-first 7538.8662109375
# current-first 7543.865478515625
# current-first 7548.8642578125
# current-first 7553.8642578125
# current-first 7558.86328125
# current-first 7563.8623046875
# current-first 7568.861328125
# current-first 7573.8603515625
# current-first 7578.8603515625
# current-first 7583.859375
# current-first 7588.858154296875
# current-first 7593.857421875
# current-first 7598.856201171875
# current-first 7603.856201171875
# current-first 7608.85546875
# current-first 7613.854248046875
# current-first 7618.853271484375
# current-first 7623.852294921875
# current-first 7628.852294921875
# current-first 7633.85107421875
# current-first 7638.850341796875
# current-first 7643.849365234375
# current-first 7648.84814453125
# current-first 7653.847412109375
# current-first 7658.847412109375
# current-first 7663.84619140625
# current-first 7668.845458984375
# current-first 7673.84423828125
# current-first 7678.84423828125
# current-first 7683.843505859375
# current-first 7688.84228515625
# current-first 7693.84130859375
# current-first 7698.84033203125
# current-first 7703.84033203125
# current-first 7708.839111328125
# current-first 7713.83837890625
# current-first 7718.83740234375
# current-first 7723.836181640625
# current-first 7728.836181640625
# current-first 7733.835205078125
# current-first 7738.834228515625
# current-first 7743.83349609375
# current-first 7748.833251953125
# current-first 7753.832275390625
# ...
# current-first 28245.897216796875
# current-first 28250.896240234375
# current-first 28255.895263671875
# current-first 28260.894287109375
# current-first 28265.894287109375
# current-first 28270.893310546875
# current-first 28275.892333984375
# current-first 28280.89111328125
# current-first 28285.890380859375
# current-first 28290.890380859375
# current-first 28295.88916015625
# current-first 28300.88818359375
# current-first 28305.88720703125
# current-first 28310.88720703125
# current-first 28315.88623046875
# current-first 28320.88525390625
# current-first 28325.88427734375
# current-first 28330.884033203125
# current-first 28335.88330078125
# current-first 28340.88232421875
# current-first 28345.881103515625
# current-first 28350.88134765625
# current-first 28355.88037109375
# current-first 28360.879150390625
# current-first 28365.87841796875
# current-first 28370.878173828125
# current-first 28375.877197265625
# current-first 28380.87646484375
# current-first 28385.876220703125
# current-first 28390.875244140625
# current-first 28395.874267578125
# current-first 28400.873291015625
# current-first 28405.8720703125
# current-first 28410.871337890625
# current-first 28415.871337890625
# current-first 28420.8701171875
# current-first 28425.869384765625
# current-first 28430.869384765625
# current-first 28435.8681640625
# current-first 28440.8671875
# current-first 28445.8662109375
# current-first 28450.8662109375
# current-first 28455.865234375
# current-first 28460.8642578125
# current-first 28465.86328125
# current-first 28470.862060546875
# current-first 28475.8623046875
# current-first 28480.861328125
# current-first 28485.860107421875
# current-first 28490.859375
# current-first 28495.859375
# current-first 28500.858154296875
# current-first 28505.857421875
# current-first 28510.856201171875
# current-first 28515.856201171875
# current-first 28520.85546875
# current-first 28525.854248046875
# current-first 28530.853271484375
# current-first 28535.853271484375
# current-first 28540.852294921875
# current-first 28545.85107421875
# current-first 28550.85107421875
# current-first 28555.850341796875
# current-first 28560.84912109375
# current-first 28565.758544921875
# current-first 28570.75732421875
# current-first 28575.75732421875
# current-first 28580.75634765625
# current-first 28585.75537109375
# current-first 28590.75439453125
# current-first 28595.753173828125
# current-first 28600.75341796875
# current-first 28605.75244140625
# current-first 28610.751220703125
# current-first 28615.75048828125
# current-first 28620.75048828125
# current-first 28625.749267578125
# current-first 28630.74853515625
# current-first 28635.747314453125
# current-first 28640.747314453125
# current-first 28645.74658203125
# current-first 28650.745361328125
# current-first 28655.744384765625
# current-first 28660.74462890625
# current-first 28665.743408203125
# current-first 28670.742431640625
# current-first 28675.741455078125
# current-first 28680.741455078125
# current-first 28685.740234375
# current-first 28690.739501953125
# current-first 28695.738525390625
# current-first 28700.73828125
# current-first 28705.7373046875
# current-first 28710.736328125
# current-first 28715.7353515625
# current-first 28720.734375
# current-first 28725.734375
# current-first 28730.7333984375
# current-first 28735.732177734375
# current-first 28740.7314453125
# current-first 28745.7314453125
# current-first 28750.730224609375
# current-first 28755.7294921875
# current-first 28760.728271484375
# current-first 28765.728271484375
# current-first 28770.7275390625
# current-first 28775.726318359375
# current-first 28780.725341796875
# current-first 28785.724365234375
# current-first 28790.724365234375
# current-first 28795.723388671875
# current-first 28800.722412109375
# current-first 28805.721435546875
# current-first 28810.721435546875
# current-first 28815.720458984375
# current-first 28820.719482421875
# current-first 28825.71826171875
# current-first 28830.718505859375
# current-first 28835.717529296875
# current-first 28840.71630859375
# current-first 28845.71630859375
# current-first 28850.71533203125
# current-first 28855.71435546875
# current-first 28860.71337890625
# current-first 28865.71240234375
# current-first 28870.71240234375
# current-first 28875.711181640625
# current-first 28880.71044921875
# current-first 28885.70947265625
# current-first 28890.709228515625
# current-first 28895.70849609375
# current-first 28900.707275390625
# current-first 28905.706298828125
# current-first 28910.70556640625
# current-first 28915.705322265625
# current-first 28920.704345703125
# current-first 28925.703369140625
# current-first 28930.703369140625
# current-first 28935.702392578125
# current-first 28940.701416015625
# current-first 28945.700439453125
# current-first 28950.700439453125
# current-first 28955.699462890625
# current-first 28960.698486328125
# current-first 28965.697265625
# current-first 28970.696533203125
# current-first 28975.696533203125
# current-first 28980.6953125
# current-first 28985.6943359375
# current-first 28990.693359375
# current-first 28995.693359375
# current-first 29000.6923828125
# current-first 29005.69140625
# current-first 29010.6904296875
# current-first 29015.690185546875
# current-first 29020.689453125
# current-first 29025.6884765625
# current-first 29030.687255859375
# current-first 29035.6875
# current-first 29040.686279296875
# current-first 29045.685302734375
# current-first 29050.6845703125
# current-first 29055.684326171875
# current-first 29060.683349609375
# current-first 29065.770751953125
# current-first 29070.769775390625
# current-first 29075.7685546875
# current-first 29080.768798828125
# current-first 29085.767822265625
# current-first 29090.7666015625
# current-first 29095.7666015625
# current-first 29100.765869140625
# current-first 29105.7646484375
# current-first 29110.763916015625
# current-first 29115.7626953125
# current-first 29120.7626953125
# current-first 29125.761474609375
# current-first 29130.7607421875
# current-first 29135.759765625
# current-first 29140.759521484375
# current-first 29145.7587890625
# current-first 29150.7578125
# current-first 29155.757568359375
# current-first 29160.7568359375
# current-first 29165.755615234375
# current-first 29170.754638671875
# current-first 29175.75390625
# current-first 29180.753662109375
# current-first 29185.752685546875
# current-first 29190.751708984375
# current-first 29195.750732421875
# current-first 29200.750732421875
# current-first 29205.749755859375
# current-first 29210.748779296875
# current-first 29215.74755859375
# current-first 29220.746826171875
# current-first 29225.746826171875
# current-first 29230.74560546875
# current-first 29235.744873046875
# current-first 29240.74365234375
# current-first 29245.74365234375
# current-first 29250.742919921875
# current-first 29255.74169921875
# current-first 29260.74072265625
# current-first 29265.74072265625
# current-first 29270.73974609375
# current-first 29275.73876953125
# current-first 29280.737548828125
# current-first 29285.73779296875
# current-first 29290.73681640625
# current-first 29295.735595703125
# current-first 29300.73486328125
# current-first 29305.734619140625
# current-first 29310.733642578125
# current-first 29315.73291015625
# current-first 29320.732666015625
# current-first 29325.731689453125
# current-first 29330.730712890625
# current-first 29335.729736328125
# current-first 29340.728515625
# current-first 29345.728759765625
# current-first 29350.727783203125
# current-first 29355.7265625
# current-first 29360.725830078125
# current-first 29365.725830078125
# current-first 29370.724609375
# current-first 29375.723876953125
# current-first 29380.72265625
# current-first 29385.7216796875
# current-first 29390.7216796875
# current-first 29395.720703125
# current-first 29400.7197265625
# current-first 29405.718505859375
# current-first 29410.71875
# current-first 29415.7177734375
# current-first 29420.716552734375
# current-first 29425.7158203125
# current-first 29430.7158203125
# current-first 29435.714599609375
# current-first 29440.7138671875
# current-first 29445.712646484375
# current-first 29450.712646484375
# current-first 29455.7119140625
# current-first 29460.710693359375
# current-first 29465.709716796875
# current-first 29470.708740234375
# current-first 29475.708740234375
# current-first 29480.707763671875
# current-first 29485.706787109375
# current-first 29490.706787109375
# current-first 29495.70556640625
# current-first 29500.704833984375
# current-first 29505.703857421875
# current-first 29510.70263671875
# current-first 29515.702880859375
# current-first 29520.70166015625
# current-first 29525.70068359375
# current-first 29530.70068359375
# current-first 29535.69970703125
# current-first 29540.69873046875
# current-first 29545.697509765625
# current-first 29550.69775390625
# current-first 29555.69677734375
# current-first 29560.695556640625
# current-first 29565.69482421875
# current-first 29570.681640625
# current-first 29575.681640625
# current-first 29580.6806640625
# current-first 29585.6796875
# current-first 29590.678466796875
# current-first 29595.6787109375
# current-first 29600.677734375
# current-first 29605.676513671875
# current-first 29610.67578125
# current-first 29615.67578125
# current-first 29620.674560546875
# current-first 29625.673828125
# current-first 29630.672607421875
# current-first 29635.671630859375
# current-first 29640.671875
# current-first 29645.670654296875
# current-first 29650.669677734375
# current-first 29655.668701171875
# current-first 29660.668701171875
# current-first 29665.667724609375
# current-first 29670.666748046875
# current-first 29675.665771484375
# current-first 29680.665771484375
# current-first 29685.66455078125
# current-first 29690.663818359375
# current-first 29695.66357421875
# current-first 29700.66259765625
# current-first 29705.661865234375
# current-first 29710.66064453125
# current-first 29715.65966796875
# current-first 29720.65966796875
# current-first 29725.65869140625
# current-first 29730.65771484375
# current-first 29735.65771484375
# current-first 29740.65673828125
# current-first 29745.655517578125
# current-first 29750.65478515625
# current-first 29755.65380859375
# current-first 29760.653564453125
# current-first 29765.65283203125
# current-first 29770.651611328125
# current-first 29775.650634765625
# current-first 29780.64990234375
# current-first 29785.649658203125
# current-first 29790.648681640625
# current-first 29795.647705078125
# current-first 29800.646728515625
# current-first 29805.646728515625
# current-first 29810.6455078125
# current-first 29815.644775390625
# current-first 29820.6435546875
# current-first 29825.6435546875
# current-first 29830.642822265625
# current-first 29835.6416015625
# current-first 29840.640625
# current-first 29845.640869140625
# current-first 29850.6396484375
# current-first 29855.638671875
# current-first 29860.6376953125
# current-first 29865.63671875
# current-first 29870.63671875
# current-first 29875.6357421875
# current-first 29880.634765625
# current-first 29885.634521484375
# current-first 29890.6337890625
# current-first 29895.6328125
# current-first 29900.631591796875
# current-first 29905.6318359375
# current-first 29910.630615234375
# current-first 29915.629638671875
# current-first 29920.62890625
# current-first 29925.628662109375
# current-first 29930.627685546875
# current-first 29935.626708984375
# current-first 29940.625732421875
# current-first 29945.624755859375
# current-first 29950.62451171875
# current-first 29955.623779296875
# current-first 29960.62255859375
# current-first 29965.62255859375
# current-first 29970.621826171875
# current-first 29975.62060546875
# current-first 29980.61962890625
# current-first 29985.619873046875
# current-first 29990.61865234375
# current-first 29995.61767578125
# current-first 30000.61669921875
# current-first 30005.61572265625
# current-first 30010.61572265625
# current-first 30015.61474609375
# current-first 30020.61376953125
# current-first 30025.612548828125
# current-first 30030.61279296875
# current-first 30035.61181640625
# current-first 30040.610595703125
# current-first 30045.60986328125
# current-first 30050.608642578125
# current-first 30055.608642578125
# current-first 30060.60791015625
# current-first 30065.606689453125
# current-first 30070.61474609375
# current-first 30075.61376953125
# current-first 30080.613037109375
# current-first 30085.61181640625
# current-first 30090.61083984375
# current-first 30095.61083984375
# current-first 30100.60986328125
# current-first 30105.608642578125
# current-first 30110.60791015625
# current-first 30115.60791015625
# current-first 30120.606689453125
# current-first 30125.60595703125
# current-first 30130.60498046875
# current-first 30135.604736328125
# current-first 30140.60400390625
# current-first 30145.602783203125
# current-first 30150.601806640625
# current-first 30155.60205078125
# current-first 30160.600830078125
# current-first 30165.599853515625
# current-first 30170.598876953125
# current-first 30175.597900390625
# current-first 30180.597900390625
# current-first 30185.596923828125
# current-first 30190.595947265625
# current-first 30195.595947265625
# current-first 30200.594970703125
# current-first 30205.593994140625
# current-first 30210.5927734375
# current-first 30215.592041015625
# current-first 30220.592041015625
# current-first 30225.5908203125
# current-first 30230.58984375
# current-first 30235.5888671875
# current-first 30240.5888671875
# current-first 30245.587890625
# current-first 30250.5869140625
# current-first 30255.5859375
# current-first 30260.585693359375
# current-first 30265.5849609375
# current-first 30270.583984375
# current-first 30275.582763671875
# current-first 30280.5830078125
# current-first 30285.581787109375
# current-first 30290.580810546875
# current-first 30295.580078125
# current-first 30300.579833984375
# current-first 30305.578857421875
# current-first 30310.577880859375
# current-first 30315.576904296875
# current-first 30320.576904296875
# current-first 30325.575927734375
# current-first 30330.574951171875
# current-first 30335.57373046875
# current-first 30340.57373046875
# current-first 30345.572998046875
# current-first 30350.57177734375
# current-first 30355.57080078125
# current-first 30360.571044921875
# current-first 30365.56982421875
# current-first 30370.56884765625
# current-first 30375.56787109375
# current-first 30380.56689453125
# current-first 30385.56689453125
# current-first 30390.56591796875
# current-first 30395.56494140625
# current-first 30400.563720703125
# current-first 30405.56396484375
# current-first 30410.56298828125
# current-first 30415.561767578125
# current-first 30420.56103515625
# current-first 30425.560791015625
# current-first 30430.559814453125
# current-first 30435.55908203125
# current-first 30440.557861328125
# current-first 30445.557861328125
# current-first 30450.556884765625
# current-first 30455.555908203125
# current-first 30460.554931640625
# current-first 30465.554931640625
# current-first 30470.553955078125
# current-first 30475.552734375
# current-first 30480.552001953125
# current-first 30485.551025390625
# current-first 30490.55078125
# current-first 30495.5498046875
# current-first 30500.548828125
# current-first 30505.548828125
# current-first 30510.5478515625
# current-first 30515.546875
# current-first 30520.5458984375
# current-first 30525.544677734375
# current-first 30530.544921875
# current-first 30535.5439453125
# current-first 30540.542724609375
# current-first 30545.5419921875
# current-first 30550.5419921875
# current-first 30555.540771484375
# current-first 30560.5400390625
# current-first 30565.538818359375
# current-first 30570.664794921875
# current-first 30575.663818359375
# current-first 30580.662841796875
# current-first 30585.661865234375
# current-first 30590.661865234375
# current-first 30595.660888671875
# current-first 30600.65966796875
# current-first 30605.658935546875
# current-first 30610.658935546875
# current-first 30615.65771484375
# current-first 30620.65673828125
# current-first 30625.65576171875
# current-first 30630.65576171875
# current-first 30635.65478515625
# current-first 30640.65380859375
# current-first 30645.65283203125
# current-first 30650.65283203125
# current-first 30655.65185546875
# current-first 30660.65087890625
# current-first 30665.649658203125
# current-first 30670.64990234375
# current-first 30675.64892578125
# current-first 30680.647705078125
# current-first 30685.64697265625
# current-first 30690.645751953125
# current-first 30695.645751953125
# current-first 30700.64501953125
# current-first 30705.643798828125
# current-first 30710.643798828125
# current-first 30715.642822265625
# current-first 30720.641845703125
# current-first 30725.640869140625
# reached the first frame - reading bag file completed

# %%
len(t265_time_list)
# Out:
# 6147

# %% [markdown]
# ### D435i

# %%
# Setup:
cfg = rs.config()
cfg.enable_device_from_file(d435_filename)
cfg.enable_stream(rs.stream.depth, 848, 480, rs.format.z16, 30)
pipe = rs.pipeline()
profile = pipe.start(cfg)

d435_data_list = []
d435_time_list = []
# a = np.array([])
# l = []
first_timestamp = None
counter = 0
while(True):

    frames = pipe.wait_for_frames()
    depth_frame = frames.get_depth_frame()
#     print('\ndepth_frame.get_timestamp()',depth_frame.get_timestamp())
    
    if depth_frame.get_timestamp() == first_timestamp:
        print('reached the first frame - reading bag file completed')
        print('timestamp',depth_frame.get_timestamp())
        break
    if first_timestamp is None:
        first_timestamp = depth_frame.get_timestamp()
        print('first_timestamp',first_timestamp)
    print('current-first',depth_frame.get_timestamp()-first_timestamp)
    
    
    
    # to do it first go and find timestampsmof key frames
        depth_frame1 = depth_frame
    if depth_frame.get_timestamp() == 1585059293549.9937:
        depth_frame2 = depth_frame
    
    
#     depth_image = np.asanyarray(depth_frame.get_data())
#     depth_image = cv2.convertScaleAbs(depth_image, alpha=0.03)
#     cv2.imshow('D435 Depth Frame', depth_image)
#     cv2.waitKey(1)
    
#     counter+=1
#     if counter%30==0:
#         a = np.hstack((a, depth_frame))
#         l.append(depth_frame)
    
    d435_data_list.append(np.asanyarray(depth_frame.get_data()).copy())
    d435_time_list.append(depth_frame.get_timestamp())

cv2.destroyAllWindows()
pipe.stop()
# Out:
# first_timestamp 1585059272738.613
# current-first 0.0
# current-first 32.364013671875
# current-first 65.6904296875
# current-first 98.64453125
# current-first 131.9052734375
# current-first 165.260009765625
# current-first 198.619384765625
# current-first 231.972412109375
# current-first 265.320556640625
# current-first 298.669921875
# current-first 332.087646484375
# current-first 365.589111328125
# current-first 398.846923828125
# current-first 432.1474609375
# current-first 465.772216796875
# current-first 498.96435546875
# current-first 532.234375
# current-first 565.82763671875
# current-first 598.99462890625
# current-first 632.35302734375
# current-first 665.62646484375
# current-first 698.97509765625
# current-first 732.40380859375
# current-first 765.72802734375
# current-first 799.047119140625
# current-first 832.42724609375
# current-first 865.82275390625
# current-first 899.141357421875
# current-first 932.950927734375
# current-first 966.539306640625
# current-first 999.246826171875
# current-first 1032.65673828125
# current-first 1065.99853515625
# current-first 1099.4267578125
# current-first 1132.755615234375
# current-first 1165.992919921875
# current-first 1199.40576171875
# current-first 1232.71826171875
# current-first 1266.46533203125
# current-first 1299.46435546875
# current-first 1332.75537109375
# current-first 1366.0830078125
# current-first 1399.471923828125
# current-first 1433.196044921875
# current-first 1466.3974609375
# current-first 1499.55712890625
# current-first 1532.884033203125
# current-first 1566.254638671875
# current-first 1599.5283203125
# current-first 1633.01220703125
# current-first 1666.330078125
# current-first 1699.732177734375
# current-first 1733.010498046875
# current-first 1766.37060546875
# current-first 1799.693359375
# current-first 1833.11669921875
# current-first 1866.61474609375
# current-first 1899.83642578125
# current-first 1933.1923828125
# current-first 1967.3037109375
# current-first 2000.29248046875
# current-first 2033.2216796875
# current-first 2066.794677734375
# current-first 2099.92138671875
# current-first 2133.23046875
# current-first 2166.63037109375
# current-first 2200.069580078125
# current-first 2233.292236328125
# current-first 2266.676513671875
# current-first 2299.9697265625
# current-first 2333.336669921875
# current-first 2366.77392578125
# current-first 2400.0634765625
# current-first 2433.356689453125
# current-first 2467.0107421875
# current-first 2500.16064453125
# current-first 2533.4677734375
# current-first 2566.882568359375
# current-first 2600.197509765625
# current-first 2633.62451171875
# current-first 2666.96826171875
# current-first 2700.276123046875
# current-first 2733.59814453125
# current-first 2766.9853515625
# current-first 2800.27734375
# current-first 2833.649658203125
# current-first 2867.215576171875
# current-first 2900.408203125
# current-first 2933.730712890625
# current-first 2967.103759765625
# current-first 3000.426513671875
# current-first 3033.81103515625
# current-first 3067.125732421875
# current-first 3100.50048828125
# current-first 3133.9580078125
# current-first 3167.43310546875
# current-first 3200.61962890625
# current-first 3233.89599609375
# current-first 3267.27734375
# current-first 3300.662109375
# current-first 3334.14404296875
# current-first 3367.842529296875
# current-first 3400.761962890625
# current-first 3434.07373046875
# current-first 3467.345458984375
# current-first 3501.021240234375
# current-first 3534.108642578125
# current-first 3567.474609375
# current-first 3600.828369140625
# current-first 3635.17138671875
# current-first 3667.5224609375
# current-first 3700.912353515625
# current-first 3734.3349609375
# current-first 3767.525146484375
# current-first 3800.91064453125
# current-first 3834.37451171875
# current-first 3867.614501953125
# current-first 3901.177978515625
# current-first 3934.428955078125
# current-first 3967.720703125
# current-first 4001.556396484375
# current-first 4034.439208984375
# current-first 4067.967041015625
# current-first 4101.163330078125
# current-first 4134.49462890625
# current-first 4167.803955078125
# current-first 4201.649169921875
# current-first 4234.5341796875
# current-first 4267.922607421875
# current-first 4301.377197265625
# current-first 4334.592041015625
# current-first 4367.980224609375
# current-first 4401.28125
# current-first 4434.73291015625
# current-first 4468.020263671875
# current-first 4501.356689453125
# current-first 4534.739013671875
# current-first 4568.107421875
# current-first 4601.420654296875
# current-first 4634.8134765625
# current-first 4668.339111328125
# current-first 4701.559326171875
# current-first 4734.8076171875
# current-first 4768.376953125
# current-first 4801.54736328125
# current-first 4834.872802734375
# current-first 4868.31884765625
# current-first 4901.589111328125
# current-first 4934.912353515625
# current-first 4968.265869140625
# current-first 5001.6591796875
# current-first 5035.0595703125
# current-first 5068.36376953125
# current-first 5101.7314453125
# current-first 5135.08935546875
# current-first 5169.0986328125
# current-first 5201.822509765625
# current-first 5235.183837890625
# current-first 5268.634765625
# current-first 5301.80419921875
# current-first 5335.214111328125
# current-first 5368.78759765625
# current-first 5402.474853515625
# current-first 5435.2822265625
# current-first 5468.627197265625
# current-first 5501.96533203125
# current-first 5535.405517578125
# current-first 5568.696533203125
# current-first 5602.023193359375
# current-first 5635.35986328125
# current-first 5668.75537109375
# current-first 5702.118408203125
# current-first 5735.61328125
# current-first 5768.78076171875
# current-first 5802.134521484375
# current-first 5836.367431640625
# current-first 5868.853759765625
# current-first 5902.179931640625
# current-first 5935.61669921875
# current-first 5968.9208984375
# current-first 6002.30078125
# current-first 6035.69677734375
# current-first 6068.967041015625
# current-first 6102.873046875
# current-first 6136.197509765625
# current-first 6169.519775390625
# current-first 6202.75830078125
# current-first 6236.157470703125
# current-first 6269.369140625
# current-first 6303.0615234375
# current-first 6336.31103515625
# current-first 6369.849609375
# current-first 6402.65673828125
# current-first 6436.2998046875
# current-first 6469.701171875
# current-first 6503.212158203125
# current-first 6536.087646484375
# current-first 6569.79052734375
# current-first 6602.9931640625
# current-first 6636.19677734375
# current-first 6669.379638671875
# current-first 6702.712158203125
# current-first 6736.354736328125
# current-first 6769.37646484375
# current-first 6802.733154296875
# current-first 6836.4443359375
# current-first 6869.782958984375
# current-first 6902.9052734375
# current-first 6936.155517578125
# current-first 6969.515625
# current-first 7002.903564453125
# current-first 7036.29931640625
# current-first 7069.839599609375
# current-first 7103.237060546875
# current-first 7136.330078125
# current-first 7169.65234375
# current-first 7203.009033203125
# current-first 7236.31298828125
# current-first 7269.74853515625
# current-first 7303.039306640625
# current-first 7336.37548828125
# current-first 7369.778076171875
# current-first 7403.17724609375
# current-first 7436.46142578125
# current-first 7470.234130859375
# current-first 7503.31591796875
# current-first 7536.574951171875
# current-first 7569.92236328125
# current-first 7603.342529296875
# current-first 7636.750732421875
# current-first 7670.4375
# current-first 7703.356689453125
# current-first 7736.678955078125
# current-first 7770.01318359375
# current-first 7803.39990234375
# current-first 7836.75732421875
# current-first 7870.357666015625
# current-first 7903.428466796875
# current-first 7936.972412109375
# current-first 7970.142333984375
# current-first 8003.4609375
# current-first 8036.795654296875
# current-first 8070.408203125
# current-first 8103.926025390625
# current-first 8137.304931640625
# current-first 8170.339599609375
# current-first 8203.6962890625
# current-first 8236.991455078125
# current-first 8270.54052734375
# current-first 8304.025634765625
# current-first 8337.140625
# current-first 8370.44287109375
# current-first 8403.947021484375
# current-first 8437.157958984375
# current-first 8470.524658203125
# current-first 8504.323486328125
# current-first 8537.714111328125
# current-first 8570.51953125
# current-first 8603.963623046875
# current-first 8637.33544921875
# current-first 8670.587646484375
# current-first 8704.1591796875
# current-first 8737.276611328125
# current-first 8770.69482421875
# current-first 8804.00048828125
# current-first 8837.44384765625
# current-first 8870.922607421875
# current-first 8904.041259765625
# current-first 8937.414794921875
# current-first 8970.74365234375
# current-first 9004.131103515625
# current-first 9037.5234375
# current-first 9070.91943359375
# current-first 9104.188720703125
# current-first 9137.487548828125
# current-first 9170.879638671875
# current-first 9204.4130859375
# current-first 9237.685546875
# current-first 9270.93994140625
# current-first 9304.329833984375
# current-first 9337.723388671875
# current-first 9371.021240234375
# current-first 9404.494873046875
# current-first 9437.6923828125
# current-first 9471.15478515625
# current-first 9504.37451171875
# current-first 9537.784423828125
# current-first 9571.24609375
# current-first 9604.480224609375
# current-first 9637.7802734375
# current-first 9671.228515625
# current-first 9704.627197265625
# current-first 9737.8681640625
# current-first 9771.18310546875
# current-first 9804.661376953125
# current-first 9838.06982421875
# current-first 9871.497802734375
# current-first 9904.677734375
# current-first 9938.310546875
# current-first 9971.3701171875
# current-first 10005.02734375
# current-first 10038.098876953125
# current-first 10071.601806640625
# current-first 10104.8916015625
# current-first 10138.30078125
# current-first 10171.517822265625
# current-first 10204.84912109375
# current-first 10238.22998046875
# current-first 10271.5986328125
# current-first 10304.90234375
# current-first 10338.255615234375
# current-first 10371.944091796875
# current-first 10404.933837890625
# current-first 10438.28125
# current-first 10471.72119140625
# current-first 10505.472412109375
# current-first 10538.486083984375
# current-first 10571.82568359375
# current-first 10605.0498046875
# current-first 10638.47314453125
# current-first 10671.790283203125
# current-first 10705.206298828125
# current-first 10738.608154296875
# current-first 10771.9052734375
# current-first 10805.26416015625
# current-first 10838.644775390625
# current-first 10872.15283203125
# current-first 10906.029052734375
# current-first 10938.68310546875
# current-first 10972.22998046875
# current-first 11005.37451171875
# current-first 11038.696044921875
# current-first 11072.041015625
# current-first 11105.953125
# current-first 11139.0205078125
# current-first 11172.117919921875
# current-first 11205.4365234375
# current-first 11238.76806640625
# current-first 11272.194091796875
# current-first 11306.476318359375
# current-first 11338.89599609375
# current-first 11372.389404296875
# current-first 11405.569580078125
# current-first 11439.0478515625
# current-first 11472.27294921875
# current-first 11505.685302734375
# current-first 11539.115478515625
# current-first 11572.33056640625
# current-first 11605.656494140625
# current-first 11639.04541015625
# current-first 11672.628173828125
# current-first 11705.739990234375
# current-first 11739.142578125
# current-first 11772.649658203125
# current-first 11805.994140625
# current-first 11839.18359375
# current-first 11872.50390625
# current-first 11906.0048828125
# current-first 11939.411376953125
# current-first 11972.6064453125
# current-first 12005.944580078125
# current-first 12039.45361328125
# current-first 12072.926513671875
# current-first 12106.015625
# current-first 12139.345703125
# current-first 12172.87744140625
# current-first 12206.283935546875
# current-first 12239.49951171875
# current-first 12272.945556640625
# current-first 12306.2880859375
# current-first 12339.799560546875
# current-first 12372.877685546875
# current-first 12406.26318359375
# current-first 12439.599853515625
# current-first 12472.918212890625
# current-first 12506.237548828125
# current-first 12539.717529296875
# current-first 12572.9951171875
# current-first 12606.446533203125
# current-first 12639.84130859375
# current-first 12673.025390625
# current-first 12706.935791015625
# current-first 12740.165771484375
# current-first 12773.408447265625
# current-first 12806.462646484375
# current-first 12839.873291015625
# current-first 12873.2197265625
# current-first 12906.62451171875
# current-first 12940.05126953125
# current-first 12973.218505859375
# current-first 13006.7158203125
# current-first 13039.988525390625
# current-first 13073.290283203125
# current-first 13106.673583984375
# current-first 13140.016357421875
# current-first 13173.410400390625
# current-first 13206.6787109375
# current-first 13240.013671875
# current-first 13273.419921875
# current-first 13306.79248046875
# current-first 13340.331787109375
# current-first 13373.55126953125
# current-first 13407.188720703125
# current-first 13440.18212890625
# current-first 13473.665771484375
# current-first 13506.83984375
# current-first 13540.591552734375
# current-first 13573.767333984375
# current-first 13606.873046875
# current-first 13640.2939453125
# current-first 13673.893310546875
# current-first 13707.012451171875
# current-first 13740.764892578125
# current-first 13773.702880859375
# current-first 13807.054443359375
# current-first 13840.6435546875
# current-first 13873.82861328125
# current-first 13907.08056640625
# current-first 13940.64892578125
# current-first 13973.995849609375
# current-first 14007.132080078125
# current-first 14040.47802734375
# current-first 14073.89306640625
# current-first 14107.25048828125
# current-first 14140.5947265625
# current-first 14173.9873046875
# current-first 14208.219970703125
# current-first 14240.72412109375
# current-first 14274.033447265625
# current-first 14307.308837890625
# current-first 14340.750732421875
# current-first 14374.109619140625
# current-first 14407.406494140625
# current-first 14440.7490234375
# current-first 14474.1943359375
# current-first 14507.499267578125
# current-first 14540.84326171875
# current-first 14574.175048828125
# current-first 14607.674560546875
# current-first 14640.891845703125
# current-first 14674.262939453125
# current-first 14707.59375
# current-first 14740.98095703125
# current-first 14774.327880859375
# current-first 14807.6611328125
# current-first 14841.042236328125
# current-first 14874.4169921875
# current-first 14907.746337890625
# current-first 14943.468505859375
# current-first 14974.445068359375
# current-first 15007.78955078125
# current-first 15041.16357421875
# current-first 15074.4912109375
# current-first 15107.80712890625
# current-first 15141.201416015625
# current-first 15174.576171875
# current-first 15207.915771484375
# current-first 15241.26025390625
# current-first 15274.634521484375
# current-first 15307.993408203125
# current-first 15341.287841796875
# current-first 15374.681884765625
# current-first 15408.07421875
# current-first 15441.391845703125
# current-first 15474.7451171875
# current-first 15508.087646484375
# current-first 15541.433837890625
# current-first 15574.918701171875
# current-first 15608.2724609375
# current-first 15641.522705078125
# current-first 15674.908203125
# current-first 15708.253662109375
# current-first 15741.52099609375
# current-first 15775.95556640625
# current-first 15808.28125
# current-first 15841.681396484375
# current-first 15874.99755859375
# current-first 15908.364013671875
# current-first 15941.929443359375
# current-first 15975.01611328125
# current-first 16008.379638671875
# current-first 16041.763916015625
# current-first 16075.126953125
# current-first 16108.4560546875
# current-first 16141.82470703125
# current-first 16178.23583984375
# current-first 16208.615966796875
# current-first 16242.133056640625
# current-first 16275.398681640625
# current-first 16308.6328125
# current-first 16341.9892578125
# current-first 16375.315185546875
# current-first 16408.73974609375
# current-first 16441.98388671875
# current-first 16475.410400390625
# current-first 16508.728515625
# current-first 16542.060546875
# current-first 16575.62744140625
# current-first 16608.769775390625
# current-first 16642.16552734375
# current-first 16675.664306640625
# current-first 16709.41357421875
# current-first 16742.186279296875
# current-first 16775.546630859375
# current-first 16809.07177734375
# current-first 16842.528076171875
# current-first 16875.61279296875
# current-first 16908.954345703125
# current-first 16942.374755859375
# current-first 16975.642822265625
# current-first 17009.114013671875
# current-first 17042.378173828125
# current-first 17075.713134765625
# current-first 17110.23486328125
# current-first 17142.45361328125
# current-first 17175.85400390625
# current-first 17209.527099609375
# current-first 17242.479248046875
# current-first 17275.91259765625
# current-first 17309.240234375
# current-first 17342.5947265625
# current-first 17375.962158203125
# current-first 17409.46923828125
# current-first 17442.633544921875
# current-first 17475.99267578125
# current-first 17509.42919921875
# current-first 17542.854248046875
# current-first 17576.237548828125
# current-first 17609.589111328125
# current-first 17643.459716796875
# current-first 17676.140380859375
# current-first 17709.812744140625
# current-first 17742.8505859375
# current-first 17776.23046875
# current-first 17809.529052734375
# current-first 17843.444091796875
# current-first 17877.308837890625
# current-first 17909.65869140625
# current-first 17942.952880859375
# current-first 17976.346923828125
# current-first 18009.655029296875
# current-first 18043.059326171875
# current-first 18076.3701171875
# current-first 18109.759765625
# current-first 18143.07958984375
# current-first 18176.479736328125
# current-first 18209.75830078125
# current-first 18243.130126953125
# current-first 18276.477294921875
# current-first 18309.884765625
# current-first 18343.191162109375
# current-first 18376.5869140625
# current-first 18410.087158203125
# current-first 18443.265625
# current-first 18476.666748046875
# current-first 18510.0029296875
# current-first 18543.320556640625
# current-first 18577.076416015625
# current-first 18610.040283203125
# current-first 18643.38671875
# current-first 18676.77783203125
# current-first 18710.552734375
# current-first 18744.068603515625
# current-first 18776.78076171875
# current-first 18810.157958984375
# current-first 18843.461669921875
# current-first 18881.899169921875
# current-first 18910.24169921875
# current-first 18943.589111328125
# current-first 18976.853271484375
# current-first 19010.94677734375
# current-first 19044.169921875
# current-first 19077.19580078125
# current-first 19110.706298828125
# current-first 19144.166259765625
# current-first 19177.353515625
# current-first 19210.679931640625
# current-first 19244.767578125
# current-first 19277.436279296875
# current-first 19310.429443359375
# current-first 19343.85205078125
# current-first 19377.348388671875
# current-first 19410.490234375
# current-first 19443.890625
# current-first 19477.240478515625
# current-first 19510.53564453125
# current-first 19544.031494140625
# current-first 19578.71875
# current-first 19610.6455078125
# current-first 19644.27001953125
# current-first 19677.42578125
# current-first 19710.679443359375
# current-first 19744.17919921875
# current-first 19777.862060546875
# current-first 19810.81103515625
# current-first 19844.7421875
# current-first 19877.455322265625
# current-first 19910.84375
# current-first 19944.155029296875
# current-first 19978.010009765625
# current-first 20011.183349609375
# current-first 20044.84375
# current-first 20077.5517578125
# current-first 20111.54248046875
# current-first 20144.705078125
# current-first 20178.359130859375
# current-first 20211.48583984375
# current-first 20244.704833984375
# current-first 20278.1650390625
# current-first 20311.8173828125
# current-first 20344.420654296875
# current-first 20378.2744140625
# current-first 20411.53466796875
# current-first 20444.827880859375
# current-first 20478.3828125
# current-first 20511.33203125
# current-first 20544.92724609375
# current-first 20577.876220703125
# current-first 20611.234619140625
# current-first 20644.658447265625
# current-first 20677.936279296875
# current-first 20711.3671875
# current-first 20744.673095703125
# current-first 20778.034423828125
# current-first 20811.380615234375
# current-first 20844.71142578125
# current-first 20879.123779296875
# current-first 20911.401123046875
# current-first 20944.906982421875
# current-first 20978.161376953125
# current-first 21011.514404296875
# current-first 21045.93310546875
# current-first 21078.610107421875
# current-first 21111.665283203125
# current-first 21145.635986328125
# current-first 21178.921630859375
# current-first 21211.735595703125
# current-first 21245.095703125
# current-first 21278.921875
# current-first 21311.9658203125
# current-first 21345.37353515625
# current-first 21378.8974609375
# current-first 21411.870361328125
# current-first 21445.570068359375
# current-first 21478.670654296875
# current-first 21511.984375
# current-first 21545.4072265625
# current-first 21578.99951171875
# current-first 21612.111328125
# current-first 21645.279541015625
# current-first 21679.869140625
# current-first 21712.36962890625
# current-first 21745.606201171875
# current-first 21779.162841796875
# current-first 21812.63818359375
# current-first 21845.613525390625
# current-first 21878.860595703125
# current-first 21912.216064453125
# current-first 21945.65771484375
# current-first 21979.269775390625
# current-first 22012.690673828125
# current-first 22045.6494140625
# current-first 22079.48779296875
# current-first 22112.80859375
# current-first 22145.934814453125
# current-first 22179.01953125
# current-first 22212.397705078125
# current-first 22245.801513671875
# current-first 22279.177734375
# current-first 22312.599853515625
# current-first 22346.039794921875
# current-first 22379.490478515625
# current-first 22412.726318359375
# current-first 22446.079345703125
# current-first 22479.07373046875
# current-first 22512.803955078125
# current-first 22546.209716796875
# current-first 22579.60595703125
# current-first 22613.0263671875
# current-first 22645.780029296875
# current-first 22679.182373046875
# current-first 22712.725830078125
# current-first 22746.064453125
# current-first 22779.382568359375
# current-first 22812.750244140625
# current-first 22845.947509765625
# current-first 22879.297119140625
# current-first 22913.173095703125
# current-first 22946.205322265625
# current-first 22979.478515625
# current-first 23012.857666015625
# current-first 23046.39111328125
# current-first 23079.6181640625
# current-first 23112.7822265625
# current-first 23146.39208984375
# current-first 23180.00732421875
# current-first 23213.255615234375
# current-first 23247.0205078125
# current-first 23279.861572265625
# current-first 23313.173828125
# current-first 23346.55078125
# current-first 23380.199951171875
# current-first 23413.506591796875
# current-first 23446.9248046875
# current-first 23479.689697265625
# current-first 23513.18359375
# current-first 23546.742919921875
# current-first 23579.991943359375
# current-first 23613.4755859375
# current-first 23646.629150390625
# current-first 23679.734130859375
# current-first 23713.15087890625
# current-first 23746.6884765625
# current-first 23779.843505859375
# current-first 23813.5654296875
# current-first 23846.71484375
# current-first 23880.27734375
# current-first 23913.339599609375
# current-first 23946.886474609375
# current-first 23980.247802734375
# current-first 24013.75732421875
# current-first 24047.03857421875
# current-first 24080.241943359375
# current-first 24113.402099609375
# current-first 24146.8173828125
# current-first 24180.270751953125
# current-first 24213.66650390625
# current-first 24246.90185546875
# current-first 24280.258056640625
# current-first 24313.47509765625
# current-first 24346.865478515625
# current-first 24380.675537109375
# current-first 24413.850830078125
# current-first 24447.22021484375
# current-first 24481.905517578125
# current-first 24513.8779296875
# current-first 24547.215087890625
# current-first 24580.765625
# current-first 24614.152099609375
# current-first 24647.16064453125
# current-first 24680.34765625
# current-first 24713.816162109375
# current-first 24747.1640625
# current-first 24780.7861328125
# current-first 24814.22802734375
# current-first 24847.4560546875
# current-first 24880.62841796875
# current-first 24913.969482421875
# current-first 24947.232666015625
# current-first 24980.90869140625
# current-first 25014.4833984375
# current-first 25047.83203125
# current-first 25080.644775390625
# current-first 25113.958984375
# current-first 25147.38671875
# current-first 25181.10791015625
# current-first 25214.4521484375
# current-first 25247.408203125
# current-first 25280.822021484375
# current-first 25314.14501953125
# current-first 25347.481201171875
# current-first 25380.952880859375
# current-first 25414.556640625
# current-first 25447.7490234375
# current-first 25484.571533203125
# current-first 25514.331787109375
# current-first 25547.91357421875
# current-first 25581.21875
# current-first 25614.6630859375
# current-first 25648.177978515625
# current-first 25681.215087890625
# current-first 25714.339599609375
# current-first 25748.056396484375
# current-first 25781.4189453125
# current-first 25814.8935546875
# current-first 25848.05419921875
# current-first 25881.2978515625
# current-first 25914.478515625
# current-first 25948.182373046875
# current-first 25981.568359375
# current-first 26015.043212890625
# current-first 26048.1474609375
# current-first 26081.478515625
# current-first 26114.8271484375
# current-first 26147.88671875
# current-first 26181.25830078125
# current-first 26214.66259765625
# current-first 26248.129638671875
# current-first 26281.368896484375
# current-first 26314.759033203125
# current-first 26348.10595703125
# current-first 26381.679931640625
# current-first 26414.8466796875
# current-first 26448.45458984375
# current-first 26482.20703125
# current-first 26514.983154296875
# current-first 26548.885498046875
# current-first 26581.6240234375
# current-first 26615.031982421875
# current-first 26648.266845703125
# current-first 26681.665771484375
# current-first 26714.9208984375
# current-first 26748.472412109375
# current-first 26781.6201171875
# current-first 26815.01953125
# current-first 26848.358642578125
# current-first 26881.80029296875
# current-first 26915.2099609375
# current-first 26948.531005859375
# current-first 26982.301513671875
# current-first 27015.6650390625
# current-first 27048.57421875
# current-first 27081.874755859375
# current-first 27115.19921875
# current-first 27149.234619140625
# current-first 27181.982666015625
# current-first 27215.590576171875
# current-first 27248.7890625
# current-first 27281.9716796875
# current-first 27315.276611328125
# current-first 27348.65576171875
# current-first 27381.997802734375
# current-first 27415.37548828125
# current-first 27448.746826171875
# current-first 27483.710205078125
# current-first 27515.512939453125
# current-first 27548.847412109375
# current-first 27582.200927734375
# current-first 27615.53125
# current-first 27648.908447265625
# current-first 27682.415771484375
# current-first 27715.577392578125
# current-first 27748.994873046875
# current-first 27782.395263671875
# current-first 27815.64404296875
# current-first 27849.44384765625
# current-first 27882.344970703125
# current-first 27915.732177734375
# current-first 27949.10107421875
# current-first 27982.388671875
# current-first 28016.0703125
# current-first 28049.6767578125
# current-first 28082.559326171875
# current-first 28115.8974609375
# current-first 28149.153076171875
# current-first 28182.6787109375
# current-first 28216.623046875
# current-first 28249.29638671875
# current-first 28282.735595703125
# current-first 28316.02392578125
# current-first 28349.325927734375
# current-first 28382.697021484375
# current-first 28416.110107421875
# current-first 28449.355712890625
# current-first 28483.902099609375
# current-first 28516.086669921875
# current-first 28549.683349609375
# current-first 28582.818603515625
# current-first 28616.142822265625
# current-first 28649.744873046875
# current-first 28682.831787109375
# current-first 28716.345703125
# current-first 28749.628662109375
# current-first 28782.88037109375
# current-first 28816.238525390625
# current-first 28849.583740234375
# current-first 28882.953369140625
# current-first 28916.498046875
# current-first 28949.715087890625
# current-first 28983.021728515625
# current-first 29016.375
# current-first 29050.205322265625
# current-first 29083.601806640625
# current-first 29116.801513671875
# current-first 29149.946044921875
# current-first 29183.29345703125
# current-first 29217.096923828125
# current-first 29249.887939453125
# current-first 29283.187744140625
# current-first 29316.655029296875
# current-first 29349.892578125
# current-first 29383.271484375
# current-first 29416.707275390625
# current-first 29450.07421875
# current-first 29483.342041015625
# current-first 29516.710693359375
# current-first 29550.18505859375
# current-first 29583.43701171875
# current-first 29616.76220703125
# current-first 29650.115966796875
# current-first 29683.3994140625
# current-first 29716.757568359375
# current-first 29750.204345703125
# current-first 29783.695556640625
# current-first 29817.031982421875
# current-first 29850.64990234375
# current-first 29883.576171875
# current-first 29917.00634765625
# current-first 29953.829833984375
# current-first 29983.636474609375
# current-first 30017.09033203125
# current-first 30050.314208984375
# current-first 30083.711669921875
# current-first 30117.024169921875
# current-first 30150.3466796875
# current-first 30183.70751953125
# current-first 30217.111083984375
# current-first 30250.430419921875
# current-first 30286.6201171875
# current-first 30322.48779296875
# current-first 30350.513427734375
# current-first 30383.89111328125
# current-first 30417.289794921875
# current-first 30450.56591796875
# current-first 30485.33447265625
# current-first 30517.309326171875
# current-first 30550.65771484375
# current-first 30584.027099609375
# current-first 30617.397705078125
# current-first 30650.711181640625
# current-first 30684.70703125
# current-first 30717.4404296875
# current-first 30750.780029296875
# current-first 30784.063232421875
# current-first 30817.371337890625
# current-first 30850.92236328125
# current-first 30885.27197265625
# current-first 30919.2724609375
# current-first 30951.234619140625
# current-first 30984.29150390625
# reached the first frame - reading bag file completed
# timestamp 1585059272738.613

# %% [markdown]
# # TODO: submit an issue about saving limit of pyrealsense2.pyrealsense2.depth_frame objects

# %% [markdown]
# # Define key frames

# %%
number_of_keyframes = 2

# %% [markdown]
# ### 265 frames

# %%
idx1 = int(len(t265_data_list)*0.65)
idx2 = idx1 + 100 # plus 1 sec
#frame 1
t265_frame1_data = t265_data_list[idx1]
t265_frame1_time = t265_time_list[idx1]
#frame 2
t265_frame2_data = t265_data_list[idx2]
t265_frame2_time = t265_time_list[idx2]

# %% [markdown]
# ### 435 frames

# %%
idx1, val1 = min(enumerate(d435_time_list), key=lambda x: abs(x[1]-t265_frame1_time))
t265_frame1_time, idx1, val1
# Out:
# (1585059293012.0835, 608, 1585059293016.778)

# %%
idx2, val2 = min(enumerate(d435_time_list), key=lambda x: abs(x[1]-t265_frame2_time))
t265_frame2_time, idx2, val2
# Out:
# (1585059293512.0708, 623, 1585059293516.6475)

# %%
#frame 1
d435_frame1_data = d435_data_list[idx1]#depth_frame1
d435_frame1_time = d435_time_list[idx1]
#frame 2
d435_frame2_data = d435_data_list[idx2]# depth_frame2
d435_frame2_time = d435_time_list[idx2]
d435_frame1_time, d435_frame2_time
# Out:
# (1585059293016.778, 1585059293516.6475)

# %%
#frame 1
# depth_image = cv2.convertScaleAbs(d435_frame1_data, alpha=0.03)
depth_image = np.asanyarray(depth_frame1.get_data())
depth_image = cv2.convertScaleAbs(depth_image, alpha=0.03)
plt.imshow(depth_image, cmap='gray')

# %%
#frame 2
# depth_image = cv2.convertScaleAbs(d435_frame2_data, alpha=0.03)
depth_image = np.asanyarray(depth_frame2.get_data())
depth_image = cv2.convertScaleAbs(depth_image, alpha=0.03)
plt.imshow(depth_image, cmap='gray')

# %% [markdown]
# # Transformations

# %% [markdown]
# transformation between cameras
#
# $ {}^{T}T_D$ - d435 wrt t265, always the same

# %%
T_d_wrt_t = np.array([[0.999968402, -0.006753626, -0.004188075, -0.015890727],
                      [-0.006685408, -0.999848172, 0.016093893, 0.028273059],
                      [-0.004296131, -0.016065384, -0.999861654, -0.009375589],
                      [0, 0, 0, 1]])

# %%
def get_transformation(data):
#     data = pose.get_pose_data()
    data_rot = [float(i.strip('xyzw: ')) for i in str(data.rotation).split(', ')]
    r = R.from_quat(data_rot)
    rotation = np.array(r.as_matrix())
    translation = np.array([float(i.strip('xyzw: ')) for i in str(data.translation).split(', ')])[np.newaxis].T
    T = np.hstack((rotation, translation))
    T = np.vstack((T, np.array([0, 0, 0, 1])))
    return T

# %% [markdown]
# transformation of t265 wrt world
#
# $ {}^{W}T_{T}$

# %%
#frame1
T_t1_wrt_w = get_transformation(t265_frame1_data)
T_t1_wrt_w
# Out:
# array([[ 0.9548, -0.2333,  0.1841, -2.6495],
#        [ 0.1027,  0.8404,  0.5322,  0.3922],
#        [-0.2789, -0.4892,  0.8264, -0.962 ],
#        [ 0.    ,  0.    ,  0.    ,  1.    ]])

# %%
#frame2
T_t2_wrt_w = get_transformation(t265_frame2_data)
T_t2_wrt_w
# Out:
# array([[ 0.9968, -0.0698, -0.0381, -2.8258],
#        [ 0.0789,  0.8073,  0.5848,  0.3956],
#        [-0.0101, -0.586 ,  0.8103, -0.9334],
#        [ 0.    ,  0.    ,  0.    ,  1.    ]])

# %% [markdown]
# transformation of d435 wrt world
#
# $ {}^{W}T_{D1} = {}^{W}T_{T} {}^{T}T_{D1}$

# %%
#frame1
T_d1_wrt_w = T_t1_wrt_w @ T_d_wrt_t
T_d1_wrt_w
# Out:
# array([[ 0.9556,  0.2239, -0.1918, -2.673 ],
#        [ 0.0948, -0.8495, -0.519 ,  0.4094],
#        [-0.2791,  0.4777, -0.833 , -0.9791],
#        [ 0.    ,  0.    ,  0.    ,  1.    ]])

# %% [markdown]
# $ {}^{W}T_{D2} = {}^{W}T_{T} {}^{T}T_{D2}$

# %%
#frame2
T_d2_wrt_w = T_t2_wrt_w @ T_d_wrt_t
T_d2_wrt_w
# Out:
# array([[ 0.9974,  0.0637,  0.0328, -2.8432],
#        [ 0.071 , -0.8171, -0.5721,  0.4116],
#        [-0.0097,  0.5729, -0.8196, -0.9575],
#        [ 0.    ,  0.    ,  0.    ,  1.    ]])

# %% [markdown]
# transformation of keyframe2 wrt keyframe1
#
# $ {}^{W}T_{D2} = {}^{W}T_{D1} {}^{D1}T_{D2}$
#
# $ ({}^{W}T_{D1})^{-1} {}^{W}T_{D2} = {}^{D1}T_{D2}$
#
# ${}^{D1}T_{D2}$:

# %%
# keyframe 2 wtr keyframe 1
T_d2_wrt_d1 = np.linalg.inv(T_d1_wrt_w) @ T_d2_wrt_w
T_d2_wrt_d1
# Out:
# array([[ 0.9625, -0.1766,  0.2058, -0.1685],
#        [ 0.1584,  0.9821,  0.1018, -0.0297],
#        [-0.2201, -0.0653,  0.9733,  0.0134],
#        [ 0.    ,  0.    ,  0.    ,  1.    ]])

# %% [markdown]
# Now let's try to get ${}^{D1}T_{D2}$ from point cloud registration

# %% [markdown]
# # Point cloud registration

# %% [markdown]
# ### Defive PC, init, and max_point_pair_dist

# %%
def get_geom_pcl(depth_frame): #slower
    pc = rs.pointcloud()
    points = pc.calculate(depth_frame).as_points()
    coordinates = np.ndarray(buffer=points.get_vertices(), dtype=np.float32, shape=(480, 848, 3)) \
        .reshape((-1, 3))
    coordinates = coordinates[coordinates[:, 2] != 0]
    pcl = o3d.geometry.PointCloud(o3d.utility.Vector3dVector(coordinates))
    return pcl

# %%
import copy
def draw_registration_result(source, target, transformation):
    source_temp = copy.deepcopy(source)
    target_temp = copy.deepcopy(target)
    source_temp.paint_uniform_color([1, 0.706, 0])
    target_temp.paint_uniform_color([0, 0.651, 0.929])
    source_temp.transform(transformation)
    o3d.visualization.draw_geometries([source_temp, target_temp])

# %%
# %%time
pcl1 = get_geom_pcl(depth_frame1)
pcl2 = get_geom_pcl(depth_frame2)
# Out:
# Wall time: 1.2 s

# %%
init = T_d2_wrt_d1 # does not help much ?

# %%
max_point_pair_dist = 0.05

# %% [markdown]
# ### Evaliate init guess

# %%
evaluation_init = o3d.registration.evaluate_registration(pcl2, pcl1,
                                                    max_point_pair_dist, init)
evaluation_init
# Out:
# registration::RegistrationResult with fitness=8.500270e-01, inlier_rmse=1.169206e-02, and correspondence_set size of 311744
# Access transformation to get result.

# %%
draw_registration_result(pcl2, pcl1, init)

# %% [markdown]
# ### Evaluate ICP

# %% [markdown]
# #### With $init = Identity$

# %%
# %%time
T = o3d.registration.registration_icp(pcl2, pcl1, max_point_pair_dist)
T, T.transformation
# Out:
# Wall time: 16.1 s
# (registration::RegistrationResult with fitness=8.315128e-01, inlier_rmse=1.815872e-02, and correspondence_set size of 304954
#  Access transformation to get result.,
#  array([[ 0.9752, -0.1317,  0.1778, -0.1548],
#         [ 0.1266,  0.9912,  0.0397,  0.0025],
#         [-0.1815, -0.0162,  0.9833,  0.0231],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
draw_registration_result(pcl2, pcl1, T.transformation)

# %% [markdown]
# #### With $init = {}^{D1}T_{D2}$

# %%
# %%time
T_init = o3d.registration.registration_icp(pcl2, pcl1, max_point_pair_dist, init)
T_init, T_init.transformation
# Out:
# Wall time: 7.73 s
# (registration::RegistrationResult with fitness=8.595568e-01, inlier_rmse=1.126183e-02, and correspondence_set size of 315239
#  Access transformation to get result.,
#  array([[ 0.9632, -0.1794,  0.2002, -0.1783],
#         [ 0.1638,  0.9822,  0.0922, -0.0198],
#         [-0.2132, -0.056 ,  0.9754,  0.0125],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
draw_registration_result(pcl2, pcl1, T_init.transformation)

# %%
pcl3 = copy.deepcopy(pcl1)
pcl4 = copy.deepcopy(pcl2)

# %%
# %%time

pcl3.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
pcl4.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))

T_plane = o3d.registration.registration_icp(pcl4, pcl3, max_point_pair_dist, np.eye(4),\
                                          o3d.registration.TransformationEstimationPointToPlane())
T_plane, T_plane.transformation
# Out:
# Wall time: 8.82 s
# (registration::RegistrationResult with fitness=8.539561e-01, inlier_rmse=1.085674e-02, and correspondence_set size of 313185
#  Access transformation to get result.,
#  array([[ 0.9628, -0.1804,  0.2011, -0.1737],
#         [ 0.1636,  0.9817,  0.0977, -0.0217],
#         [-0.2151, -0.0612,  0.9747,  0.0109],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
# %%time
pcl3.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
pcl4.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
T_plane_init = o3d.registration.registration_icp(pcl4, pcl3, max_point_pair_dist, init,\
                                          o3d.registration.TransformationEstimationPointToPlane())
T_plane_init,T_plane_init.transformation
# Out:
# Wall time: 3.41 s
# (registration::RegistrationResult with fitness=8.539452e-01, inlier_rmse=1.085616e-02, and correspondence_set size of 313181
#  Access transformation to get result.,
#  array([[ 0.9628, -0.1804,  0.2011, -0.1737],
#         [ 0.1636,  0.9817,  0.0977, -0.0217],
#         [-0.2151, -0.0612,  0.9747,  0.0109],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %% [markdown]
# # Results

# %%
fitness_list =  [evaluation_init.fitness, T.fitness, T_init.fitness ]
rmse_list =  [evaluation_init.inlier_rmse, T.inlier_rmse, T_init.inlier_rmse ]
time_list =  [0.005, 37, 20 ]
labels =  [ '265', 'ICP with I', 'ICP with init from 265']
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, (ax0, ax, ax2) = plt.subplots(3,1)
fig.suptitle('Comparizon of different alignment methods\n (two frames are taken with 0.5 sec between them)\n ', fontsize=16)
rects0 = ax0.bar(x, fitness_list, width)
rects1 = ax.bar(x, rmse_list, width)
rects2 = ax2.bar(x, time_list, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax0.set_ylabel('Fitness Value')
ax0.set_title('Fitness')
ax0.set_xticks(x)
ax0.set_xticklabels(labels)
ax0.legend()
ax0.set_ylim([0,1])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSE Value')
ax.set_title('RMSE')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_ylim([0,0.025])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Time Value, s')
ax2.set_title('Time')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
ax2.legend()
ax2.set_ylim([0,50])

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = round(rect.get_height(),4)
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects0, ax0)
autolabel(rects1, ax)
autolabel(rects2, ax2)

fig.tight_layout()
fig.set_size_inches(5, 10)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fitness_list =  [evaluation_init.fitness, T.fitness, T_init.fitness, T_plane.fitness, T_plane_init.fitness ]
rmse_list =  [evaluation_init.inlier_rmse, T.inlier_rmse, T_init.inlier_rmse, T_plane.inlier_rmse, T_plane_init.inlier_rmse]
time_list =  [0.005, 16.1, 7.73,8.82,3.41 ]
labels =  [ '265', 'ICPtP I', 'ICPtP 265',\
           'ICPtPl I','ICPtPl 265']
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, (ax0, ax, ax2) = plt.subplots(3,1,figsize = (20,6), dpi = 80)

fig.suptitle('Comparizon of different alignment methods\n (two frames are taken with 0.5 sec between them)\n ', fontsize=16)
rects0 = ax0.bar(x, fitness_list, width)
rects1 = ax.bar(x, rmse_list, width)
rects2 = ax2.bar(x, time_list, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax0.set_ylabel('Fitness Value')
ax0.set_title('Fitness')
ax0.set_xticks(x)
ax0.set_xticklabels(labels)
ax0.legend()
ax0.set_ylim([0,1])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSE Value')
ax.set_title('RMSE')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_ylim([0,0.025])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Time Value, s')
ax2.set_title('Time')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
ax2.legend()
ax2.set_ylim([0,50])

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = round(rect.get_height(),4)
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects0, ax0)
autolabel(rects1, ax)
autolabel(rects2, ax2)

fig.tight_layout()
fig.set_size_inches(5, 10)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## With downsampling

# %%
_pcl1 = convert_to_pcl(get_coordinates(depth_frame1))
_pcl2 = convert_to_pcl(get_coordinates(depth_frame2))

# %%
draw_registration_result(_pcl2, _pcl1, init)

# %%
# %%time
_T = o3d.registration.registration_icp(_pcl2, _pcl1, max_point_pair_dist)
_T, _T.transformation
# Out:
# Wall time: 406 ms
# (registration::RegistrationResult with fitness=8.225574e-01, inlier_rmse=1.934557e-02, and correspondence_set size of 19414
#  Access transformation to get result.,
#  array([[ 0.9756,  0.1342, -0.1736, -0.1588],
#         [-0.1285,  0.9907,  0.0439, -0.0007],
#         [ 0.1779, -0.0205,  0.9838, -0.0188],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
# %%time
_T_init = o3d.registration.registration_icp(_pcl2, _pcl1, max_point_pair_dist, init)
_T_init, _T_init.transformation
# Out:
# Wall time: 394 ms
# (registration::RegistrationResult with fitness=2.901449e-01, inlier_rmse=2.308155e-02, and correspondence_set size of 6848
#  Access transformation to get result.,
#  array([[ 0.996 , -0.0509,  0.0732, -0.2241],
#         [ 0.0444,  0.9952,  0.0877,  0.0466],
#         [-0.0773, -0.0841,  0.9935, -0.0185],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
_pcl3 = copy.deepcopy(_pcl1)
_pcl4 = copy.deepcopy(_pcl2)

# %%
# %%time

_pcl3.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
_pcl4.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))

_T_plane = o3d.registration.registration_icp(_pcl4, _pcl3, max_point_pair_dist, np.eye(4),\
                                          o3d.registration.TransformationEstimationPointToPlane())
_T_plane, _T_plane.transformation
# Out:
# Wall time: 320 ms
# (registration::RegistrationResult with fitness=8.481908e-01, inlier_rmse=1.231594e-02, and correspondence_set size of 20019
#  Access transformation to get result.,
#  array([[ 0.9631,  0.1837, -0.1969, -0.1817],
#         [-0.1651,  0.9804,  0.1074,  0.0274],
#         [ 0.2128, -0.0709,  0.9745, -0.0032],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
# %%time
_pcl3.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
_pcl4.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
_T_plane_init = o3d.registration.registration_icp(_pcl4, _pcl3, max_point_pair_dist, init,\
                                          o3d.registration.TransformationEstimationPointToPlane())
_T_plane_init,_T_plane_init.transformation
# Out:
# Wall time: 434 ms
# (registration::RegistrationResult with fitness=8.525125e-01, inlier_rmse=1.265243e-02, and correspondence_set size of 20121
#  Access transformation to get result.,
#  array([[ 0.9631,  0.1832, -0.1971, -0.191 ],
#         [-0.1641,  0.9804,  0.1093,  0.0304],
#         [ 0.2133, -0.0729,  0.9743, -0.005 ],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
fitness_list =  [evaluation_init.fitness, _T.fitness, _T_init.fitness, _T_plane.fitness, _T_plane_init.fitness ]
rmse_list =  [evaluation_init.inlier_rmse, _T.inlier_rmse, _T_init.inlier_rmse, _T_plane.inlier_rmse, _T_plane_init.inlier_rmse]
time_list =  [0.005, 406, 394,320,434 ]
labels =  [ '265', 'ICPtP I', 'ICPtP 265',\
           'ICPtPl I','ICPtPl 265']
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, (ax0, ax, ax2) = plt.subplots(3,1)

fig.suptitle('Comparizon of different alignment methods\n (rs.decimation_filter)\n'\
             , fontsize=16)
rects0 = ax0.bar(x, fitness_list, width)
rects1 = ax.bar(x, rmse_list, width)
rects2 = ax2.bar(x, time_list, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax0.set_ylabel('Fitness Value')
ax0.set_title('Fitness')
ax0.set_xticks(x)
ax0.set_xticklabels(labels)
ax0.legend()
ax0.set_ylim([0,1])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSE Value')
ax.set_title('RMSE')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_ylim([0,0.05])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Time Value, ms')
ax2.set_title('Time')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
ax2.legend()
ax2.set_ylim([0,500])

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = round(rect.get_height(),4)
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects0, ax0)
autolabel(rects1, ax)
autolabel(rects2, ax2)

fig.tight_layout()
fig.set_size_inches(5, 10)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# ## Try2

# %%
# %%time
pcl1D = get_geom_pcl(depth_frame1)
pcl2D = get_geom_pcl(depth_frame2)
# Out:
# Wall time: 1.18 s

# %%
print("Downsample the point cloud with a voxel of 0.05")
downpcd1 = pcl1D.voxel_down_sample(voxel_size=0.05)
downpcd2 = pcl2D.voxel_down_sample(voxel_size=0.05)
o3d.visualization.draw_geometries([downpcd1])
# Out:
# Downsample the point cloud with a voxel of 0.05

# %%
draw_registration_result(downpcd2, downpcd1, init)

# %%
# %%time
TD = o3d.registration.registration_icp(downpcd2, downpcd1, max_point_pair_dist)
TD, TD.transformation
# Out:
# Wall time: 28.9 ms
# (registration::RegistrationResult with fitness=4.997319e-01, inlier_rmse=2.783820e-02, and correspondence_set size of 932
#  Access transformation to get result.,
#  array([[ 0.9992, -0.022 ,  0.0332, -0.0075],
#         [ 0.0227,  0.9995, -0.0209,  0.0528],
#         [-0.0327,  0.0216,  0.9992,  0.016 ],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
# %%time
TD_init = o3d.registration.registration_icp(downpcd2, downpcd1, max_point_pair_dist, init)
TD_init, TD_init.transformation
# Out:
# Wall time: 16 ms
# (registration::RegistrationResult with fitness=8.080429e-01, inlier_rmse=2.094049e-02, and correspondence_set size of 1507
#  Access transformation to get result.,
#  array([[ 0.9628, -0.1804,  0.201 , -0.1773],
#         [ 0.1644,  0.9819,  0.0937, -0.0212],
#         [-0.2142, -0.0572,  0.9751,  0.0098],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
downpcd3 = copy.deepcopy(downpcd1)
downpcd4 = copy.deepcopy(downpcd2)

# %%
# %%time

downpcd3.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
downpcd4.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))

TD_plane = o3d.registration.registration_icp(downpcd4,downpcd3, max_point_pair_dist, np.eye(4),\
                                          o3d.registration.TransformationEstimationPointToPlane())
TD_plane, TD_plane.transformation
# Out:
# Wall time: 17.9 ms
# (registration::RegistrationResult with fitness=8.075067e-01, inlier_rmse=2.109002e-02, and correspondence_set size of 1506
#  Access transformation to get result.,
#  array([[ 0.963 , -0.1798,  0.2007, -0.1769],
#         [ 0.1618,  0.9814,  0.103 , -0.0264],
#         [-0.2155, -0.0667,  0.9742,  0.0105],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
# %%time
downpcd3.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
downpcd4.estimate_normals(search_param=o3d.geometry.KDTreeSearchParamHybrid(radius=0.1, max_nn=30))
TD_plane_init = o3d.registration.registration_icp(downpcd4,downpcd3, max_point_pair_dist, init,\
                                          o3d.registration.TransformationEstimationPointToPlane())
TD_plane_init,TD_plane_init.transformation
# Out:
# Wall time: 11.9 ms
# (registration::RegistrationResult with fitness=8.069705e-01, inlier_rmse=2.105679e-02, and correspondence_set size of 1505
#  Access transformation to get result.,
#  array([[ 0.963 , -0.1799,  0.2007, -0.1768],
#         [ 0.1619,  0.9814,  0.1028, -0.0262],
#         [-0.2154, -0.0665,  0.9743,  0.0104],
#         [ 0.    ,  0.    ,  0.    ,  1.    ]]))

# %%
fitness_list =  [evaluation_init.fitness, TD.fitness, TD_init.fitness, TD_plane.fitness, TD_plane_init.fitness ]
rmse_list =  [evaluation_init.inlier_rmse, TD.inlier_rmse, TD_init.inlier_rmse, TD_plane.inlier_rmse, TD_plane_init.inlier_rmse]
time_list =  [0.005, 28.9, 16,17.9,11.9 ]
labels =  [ '265', 'ICPtP I', 'ICPtP 265',\
           'ICPtPl I','ICPtPl 265']
x = np.arange(len(labels))  # the label locations
width = 0.3  # the width of the bars

fig, (ax0, ax, ax2) = plt.subplots(3,1)

fig.suptitle('Comparizon of different alignment methods\n voxel_down_sample (0.05)\n ', fontsize=16)
rects0 = ax0.bar(x, fitness_list, width)
rects1 = ax.bar(x, rmse_list, width)
rects2 = ax2.bar(x, time_list, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax0.set_ylabel('Fitness Value')
ax0.set_title('Fitness')
ax0.set_xticks(x)
ax0.set_xticklabels(labels)
ax0.legend()
ax0.set_ylim([0,1])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('RMSE Value')
ax.set_title('RMSE')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_ylim([0,0.05])

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Time Value, ms')
ax2.set_title('Time')
ax2.set_xticks(x)
ax2.set_xticklabels(labels)
ax2.legend()
ax2.set_ylim([0,50])

def autolabel(rects, ax):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = round(rect.get_height(),4)
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects0, ax0)
autolabel(rects1, ax)
autolabel(rects2, ax2)

fig.tight_layout()
fig.set_size_inches(5, 10)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
import pyrealsense2 as rs
import cv2
import numpy as np
import time
from IPython.display import clear_output
from scipy.spatial.transform import Rotation as R
import matplotlib.pyplot as plt

# %%
def plot_pose(frames=[], poses=[], show_t=True, show_coord=True, show_pose=True, t_names=['$\mathbf{t}$']):
    """Plotting poses in frames

    Args:
        frames (list): frames to plot in addition to original frame.
        poses (list): poses to plot in the original frame.
        
        show_t (bool): depict t-vector name
        show_coord (bool): depict pose coordinates

    Returns:
        None.
    """
    def get_xyzuvctt(T):
        t = T[:3, 3:4].flatten(); t_ = t/(np.linalg.norm(t)+1e-5)*5
        R = T[:3,:3]
        (x, y, z), (u, v, c) = np.repeat(t.reshape(3,1),3, axis=1), R
        return x, y, z, u, v, c, t, t_
 
    
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111, projection='3d')
    lngth = 3

    # fig appearance
    ax.view_init(elev=22, azim=32)
#     ax.set_aspect('equal')
    ax.view_init(elev=22, azim=20)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.axis('off'); #ax.axis('equal')
    
    
    #origin and coordinate axes (coordinate frame)
    xl = 'x'; yl = 'y'; zl = 'z'; ol = 'O'
    x, y, z, u, v, c, t, t_ = get_xyzuvctt(np.eye(4))
        
    ax.scatter(t_[0], t_[1], t_[2], s=80, c='k')
    ax.quiver(x, y, z, u, v, c, color='k', length=lngth, arrow_length_ratio=0.2, linewidth=0.5)
    ax.text(0,-0.5,-0.1,ol); 
    ax.text(lngth*1.2,0,0,xl); ax.text(0,lngth*1.2,0,yl); ax.text(0,0,lngth*1.2,zl)
    # aid to have initial minimum dimensions of plot
    ax.scatter(4,4,4, alpha=0)
    
    for frame in frames:
        x, y, z, u, v, c, t, t_ = get_xyzuvctt(frame)
        ax.scatter(t_[0], t_[1], t_[2], s=80, c='k')
        ax.quiver(
            x, y, z, u, v, c, color='k', length=lngth, arrow_length_ratio=0.2, linewidth=0.5)
        xl += '\''; yl += '\''; zl += '\''; ol += '\''
        ax.text(t_[0],t_[1]-0.5,t_[2]-0.1,ol); 
        frame = frame @ np.diag([lngth*1.2, lngth*1.2, lngth*1.2, 1])
        ax.text(frame[:3,:3][0][0]+t_[0],frame[:3,:3][1][0]+t_[1], frame[:3,:3][2][0]+t_[2],xl);
        ax.text(frame[:3,:3][0][1]+t_[0],frame[:3,:3][1][1]+t_[1], frame[:3,:3][2][1]+t_[2],yl);
        ax.text(frame[:3,:3][0][2]+t_[0],frame[:3,:3][1][2]+t_[1], frame[:3,:3][2][2]+t_[2],zl);
    
    prev_t = [0, 0, 0]
    for i, pose in enumerate(poses):
        # given frame
        x, y, z, u, v, c, t, t_ = get_xyzuvctt(pose)
        ax.plot([prev_t[0], t[0]], [prev_t[1], t[1]], [prev_t[2], t[2]], color='k', linewidth=2)
        prev_t = t
  
    if show_pose:
            ax.quiver(x, y, z, u, v, c, arrow_length_ratio=0, color=['r','g','b'], linestyle='-', linewidth=4)
    if show_coord:
            ax.text(t[0], t[1], t[2]-0.7, '('+str(t[0])+','+str(t[1])+','+str(t[2])+')')
    
    plt.show()

# %%
tm = np.eye(4)
transformation_matrix_set = []
transformation_matrix_set.append(tm)

for _ in range(20):
    tm[0,-1]+=0.2 #X
    tm[1,-1]+=0.5 #Y
#     tm[2,-1]+=0.5 #Z
    transformation_matrix_set.append(tm)
    plot_pose(poses=transformation_matrix_set)
    time.sleep(0.01)
    clear_output(wait=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-157-a6e1578f8b1b> in <module>
#       8 #     tm[2,-1]+=0.5 #Z
#       9     transformation_matrix_set.append(tm)
# ---> 10     plot_pose(poses=transformation_matrix_set)
#      11     time.sleep(0.01)
#      12     clear_output(wait=True)
#
# <ipython-input-156-0af70f644b5e> in plot_pose(frames, poses, show_t, show_coord, show_pose, t_names)
#      25     # fig appearance
#      26     ax.view_init(elev=22, azim=32)
# ---> 27     ax.set_aspect('equal')
#      28     ax.view_init(elev=22, azim=20)
#      29     ax.set_xlabel('X')
#
# ~/Perception_in_Robotics/Project/perception_final_2020/venv/lib/python3.7/site-packages/matplotlib/axes/_base.py in set_aspect(self, aspect, adjustable, anchor, share)
#    1262         if (not cbook._str_equal(aspect, 'auto')) and self.name == '3d':
#    1263             raise NotImplementedError(
# -> 1264                 'It is not currently possible to manually set the aspect '
#    1265                 'on 3D axes')
#    1266
#
# NotImplementedError: It is not currently possible to manually set the aspect on 3D axes

# %%
# rewind
for i in range(frames_between_frames_D435*count_of_frames*2):
    pipe_d435.wait_for_frames()

# %%
d435_frames = []
while len(d435_frames) != count_of_frames:
    for i in range(frames_between_frames_D435):
        depth_frame = pipe_d435.wait_for_frames().get_depth_frame()
    d435_frames.append(depth_frame)

# %%
pose_frame = None
pose_frame_time = -1
thresh = 7
t265_frames = []
t265_frames_temp = []
n = 0

for i, depth_frame in enumerate(d435_frames):
    depth_frame_time = depth_frame.get_timestamp()
    while abs(depth_frame_time-pose_frame_time) > thresh:
        pose_frame = pipe_t265.wait_for_frames().get_pose_frame()
        pose_frame_time = pose_frame.get_timestamp()
    while abs(depth_frame_time-pose_frame_time) <= thresh:
        pose_frame = pipe_t265.wait_for_frames().get_pose_frame()
        t265_frames_temp.append(pose_frame)
        pose_frame_time = pose_frame.get_timestamp()

    min_int_index = 0
    min_interval = thresh * 2
    for ind_pose, temp_pose in enumerate(t265_frames_temp):
        if abs(depth_frame_time-temp_pose.get_timestamp())<min_interval:
            min_interval = abs(depth_frame_time-temp_pose.get_timestamp())
            min_int_index = ind_pose
    t265_frames.append(t265_frames_temp[min_int_index])

# %% [markdown]
# ## Test for frames

# %%
def count_diff_frames(frames):
    prev_frame = None
    for i, frame in enumerate(frames):
        if prev_frame is not None:
            print("Difference bw {0} and {1} frames is {2:.4f} ms".format(i, i-1, frame.get_timestamp()-prev_frame.get_timestamp()))
        prev_frame = frame

# %%
def get_diff_sensors(frames1, frames2):
    if len(frames1) != len(frames2):
        return
    else:
        for i in range(len(frames1)):
            print("Difference bw frames1[{0}] and frames2[{0}] frames is {1:.4f} ms".format(i, frames1[i].get_timestamp()-frames2[i].get_timestamp()))

# %%
count_diff_frames(d435_frames)
count_diff_frames(t265_frames)

# %%
get_diff_sensors(d435_frames, t265_frames)

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Helpers

# %%
import time
from functools import wraps

def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        time_start = time.time()
        result = f(*args, **kw)
        time_end = time.time()
        print('----------func:%r took: %2.4f sec' % (f.__name__, time_end-time_start))
        return result
    return wrap

# %%
tm_T265toD435 = np.array([[0.999968402, -0.006753626, -0.004188075, -0.015890727],
                          [-0.006685408, -0.999848172, 0.016093893, 0.028273059],
                          [-0.004296131, -0.016065384, -0.999861654, -0.009375589],
                          [0, 0, 0, 1]])

# %%
# Graph plot
t265 = np.load('../logs/points_trajectory_T265.npy') #np array coords
d435 = np.load('../logs/points_trajectory_D435.npy')/1 # np array coords
# before = 10
before = d435.shape[0]
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.plot(t265[:before, 0], t265[:before, 1], t265[:before, 2], label='t265')
ax.plot(d435[:before, 0], d435[:before, 1], d435[:before, 2], label='d435')
ax.view_init(elev=22, azim=80)
plt.legend()

# %% [markdown]
# ## Functions

# %%
def get_transformation(pose):
    data = pose.get_pose_data()
    data_rot = [float(i.strip('xyzw: ')) for i in str(data.rotation).split(', ')]
    r = R.from_quat(data_rot)
    rotation = np.array(r.as_matrix())
    translation = np.array([float(i.strip('xyzw: ')) for i in str(data.translation).split(', ')])[np.newaxis].T
    T = np.hstack((rotation, translation))
    T = np.vstack((T, np.array([0, 0, 0, 1])))
    return T

# %%
get_transformation(t265_frames[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-59cef9d77bad> in <module>
# ----> 1 get_transformation(t265_frames[0])
#
# NameError: name 't265_frames' is not defined

# %%
def apply_transformation(transformation, points):
    """

    :param transformation: 4x4 np.array
    :param points: Nx3 np.array
    :return: transformed Nx3 np.array
    """
    if transformation is None or points is None:
        return None
    else:
        coordinates = np.hstack((points, np.ones((points.shape[0], 1))))
        return (transformation @ coordinates.T).T[:, :-1]

# %%
def get_coordinates(depth_frame, make_sampling=True, koef = 2**2):
    """
     TODO
    :param make_sampling:
    :return:
    """
    pc = rs.pointcloud()
    if make_sampling:
        decimate = rs.decimation_filter()
        decimate.set_option(rs.option.filter_magnitude, koef)
        depth_frame = decimate.process(depth_frame)

        points = pc.calculate(depth_frame).as_points()
    else:
        points = pc.calculate(depth_frame).as_points()

    coordinates = np.ndarray(buffer=points.get_vertices(), dtype=np.float32, shape=(points.size(), 3))
    coordinates = coordinates[coordinates[:, 2] != 0]

    coordinates = apply_transformation(T_d_wrt_t, coordinates)
    return coordinates

# %%
get_coordinates(d435_frames[0]).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-0d9ff84f3081> in <module>
# ----> 1 get_coordinates(d435_frames[0]).shape
#
# NameError: name 'd435_frames' is not defined

# %%
def convert_to_pcl(points):
    """
        TODO
    :param points: Nx3
    :return:
    """
    if points is None:
        return None
    else:
        return o3d.geometry.PointCloud(o3d.utility.Vector3dVector(points))

# %%
convert_to_pcl(get_coordinates(d435_frames[0]))

# %%
# TODO this 100%

def get_transformation(self, max_point_pair_dist=0.2, init_guess=np.eye(4)):
    old_point_cloud = self.apply_transformation(self.prev_tm, self.point_cloud)
    old_pcl = self.convert_to_pcl(old_point_cloud) # n-1
    self.point_cloud = self.apply_transformation(self.prev_tm, self.get_coordinates())
    if old_pcl is None:
        self.prev_tm = init_guess
        print("\n\n\n{}\n\n\n".format(init_guess))
        return None

    new_pcl = self.convert_to_pcl(self.point_cloud) # n

    tr_mx = o3d.registration.registration_icp(old_pcl, new_pcl, max_point_pair_dist,
                                              self.prev_tm, o3d.registration.TransformationEstimationPointToPoint())\
        .transformation
    self.prev_tm = tr_mx
    return tr_mx
